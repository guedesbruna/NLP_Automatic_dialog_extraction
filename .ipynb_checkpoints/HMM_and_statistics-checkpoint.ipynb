# %% [markdown]
# ## N-grams from Jurafsky

# %%
import pandas as pd
import numpy as np
import re
from collections import Counter
import statistics

# %%
df = pd.read_csv('./data_TM2/processed_utterances_sentence_DA_labeling.csv', index_col=0)

# %%
####### correct format of column that was string and should be list

import ast

print(type(df['all_DA'][0]))
all_DA = []
for row in range(len(df['all_DA'])):
    inst = ast.literal_eval(df['all_DA'][row])
    inst = [i.strip("[]") for i in inst]
    all_DA.append(inst)
    
df['all_DA'] = all_DA

print(type(df['all_DA'][0]))
# Out:
# <class 'str'>
# <class 'list'>

# %%
df.drop(df.iloc[:, 8:-1], inplace = True, axis = 1)
df = df.explode('all_DA')
df['all_DA'] = df['all_DA'].fillna('<UNK>')
df['all_DA'].head()
# Out:
# 0          U_greeting
# 1               <UNK>
# 2          A_greeting
# 2    A_detail_request
# 3      A_confirmation
# Name: all_DA, dtype: object

# %%
#solution for all dialogues. After This data will be prepared to serve as input

unique_ids = df['conversation_id'].unique()

start = '<s>'
start_dou = '<ss>'
end_dou = '<ee>'
end ='<e>'
full_DA = []  

for dialog in unique_ids:
    dialog_DA = []   
    temp = df.loc[df['conversation_id'] == dialog]
    for x in range(len(temp)):
        dialog_DA.append(temp['all_DA'].iloc[x])

    #insert begin and end tokens for each dialog. This is for bigram only. for tri would need two symbols in the begin and 2 in the end
    dialog_DA.insert(0, start)
    dialog_DA.insert(1, start_dou)
    dialog_DA.append(end_dou)
    dialog_DA.append(end)
    full_DA.append(dialog_DA)

full_DA[0]
# Out:
# ['<s>',
#  '<ss>',
#  'U_greeting',
#  '<UNK>',
#  'A_greeting',
#  'A_detail_request',
#  'A_confirmation',
#  'U_greeting',
#  '<UNK>',
#  'A_detail_request',
#  'A_greeting',
#  'A_detail_request',
#  'U_answer',
#  '<UNK>',
#  '<UNK>',
#  '<UNK>',
#  'A_confirmation',
#  'A_detail_request',
#  'A_confirmation',
#  'A_sequence_closer',
#  '<UNK>',
#  '<UNK>',
#  '<UNK>',
#  '<UNK>',
#  'A_request_summary',
#  'A_confirmation',
#  'A_sequence_closer',
#  'U_confirmation',
#  'A_confirmation',
#  'A_sequence_closer',
#  '<UNK>',
#  'A_sequence_closer',
#  '<UNK>',
#  'U_partial_request',
#  'A_detail_request',
#  'A_grant',
#  'U_answer',
#  'A_confirmation',
#  'A_sequence_closer',
#  '<UNK>',
#  '<UNK>',
#  '<UNK>',
#  'A_confirmation',
#  'A_sequence_closer',
#  'U_sequence_closer',
#  'U_sequence_closer',
#  'A_confirmation',
#  'A_sequence_closer',
#  'A_sequence_closer',
#  '<UNK>',
#  'U_greeting',
#  'U_sequence_closer',
#  '<ee>',
#  '<e>']

# %%
#flatten nested lists

def flatten(t):
    # https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-a-list-of-lists
    return [item for sublist in t for item in sublist]

# df['labels_UNK_and_SINGLE_DA'] = flatten(ALL_DA)

# %%
#modeling phase
#from this tutorial: https://medium.com/swlh/language-modelling-with-nltk-20eac7e70853#b9bf

import nltk
from nltk.util import ngrams
# from nltk import word_tokenize

unigram=[]
bigram=[]
trigram=[]
fourgram=[]
tokenized_text = flatten(unigram)

#unigram, bigram, trigram, and fourgram models are created
for sequence in full_DA:
    unigram.append(sequence)

bigram.extend(list(ngrams(sequence, 2)))  
trigram.extend(list(ngrams(sequence, 3)))
fourgram.extend(list(ngrams(sequence, 4)))

freq_uni = Counter(flatten(unigram))
freq_bi = nltk.FreqDist(bigram)
freq_tri = nltk.FreqDist(trigram)
freq_four = nltk.FreqDist(fourgram)


print("Most common n-grams without add-1 smoothing: \n")
print ("Most common unigrams: \n", freq_uni.most_common(5))
print ("Most common bigrams: \n", freq_bi.most_common(5))
print ("\nMost common trigrams: \n", freq_tri.most_common(5))
print ("\nMost common fourgrams: \n", freq_four.most_common(5))
# Out:
# Most common n-grams without add-1 smoothing:
#
# Most common unigrams:
#  [('<UNK>', 88216), ('A_detail_request', 63851), ('U_answer', 57676), ('U_sequence_closer', 57516), ('A_greeting', 53345)]
# Most common bigrams:
#  [(('U_confirmation', 'U_sequence_closer'), 6), (('U_partial_request', 'A_grant'), 3), (('U_greeting', 'U_confirmation'), 3), (('U_sequence_closer', 'U_partial_request'), 3), (('A_grant', 'U_confirmation'), 2)]
#
# Most common trigrams:
#  [(('U_greeting', 'U_confirmation', 'U_sequence_closer'), 3), (('U_confirmation', 'U_sequence_closer', 'U_partial_request'), 3), (('A_grant', 'U_confirmation', 'U_sequence_closer'), 2), (('U_sequence_closer', 'U_partial_request', 'A_grant'), 2), (('<s>', '<ss>', 'A_greeting'), 1)]
#
# Most common fourgrams:
#  [(('U_greeting', 'U_confirmation', 'U_sequence_closer', 'U_partial_request'), 3), (('U_confirmation', 'U_sequence_closer', 'U_partial_request', 'A_grant'), 2), (('<s>', '<ss>', 'A_greeting', 'A_detail_request'), 1), (('<ss>', 'A_greeting', 'A_detail_request', 'U_partial_request'), 1), (('A_greeting', 'A_detail_request', 'U_partial_request', 'U_answer'), 1)]

# %%
# bigram

# %%
#Add-1 smoothing is performed here. Different value might be better
            
ngrams_all = {1:[], 2:[], 3:[], 4:[]} #from unigram to fourgram in this case
for i in range(4):
    for each in unigram:
        for j in ngrams(each, i+1):
            ngrams_all[i+1].append(j);
ngrams_voc = {1:set([]), 2:set([]), 3:set([]), 4:set([])} #set() method is used to convert any of the iterable to sequence of iterable elements with distinct elements

for i in range(4):
    for gram in ngrams_all[i+1]:
        if gram not in ngrams_voc[i+1]:
            ngrams_voc[i+1].add(gram)
total_ngrams = {1:-1, 2:-1, 3:-1, 4:-1}
total_voc = {1:-1, 2:-1, 3:-1, 4:-1}

for i in range(4):
    total_ngrams[i+1] = len(ngrams_all[i+1])
    total_voc[i+1] = len(ngrams_voc[i+1])                       
    
ngrams_prob = {1:[], 2:[], 3:[], 4:[]}

for i in range(4):
    for ngram in ngrams_voc[i+1]:
        tlist = [ngram]
        tlist.append(ngrams_all[i+1].count(ngram))
        ngrams_prob[i+1].append(tlist)
    
for i in range(4):
    for ngram in ngrams_prob[i+1]:
        ngram[-1] = (ngram[-1])/(total_ngrams[i+1]+total_voc[i+1])

# %%
#Prints top 10 unigram, bigram, trigram, fourgram
print("Most common n-grams without stopword removal and with add-1 smoothing: \n")
for i in range(4):
    ngrams_prob[i+1] = sorted(ngrams_prob[i+1], key = lambda x:x[1], reverse = True)
    
print ("Most common unigrams: ", str(ngrams_prob[1][:10]))
print ("\nMost common bigrams: ", str(ngrams_prob[2][:10]))
print ("\nMost common trigrams: ", str(ngrams_prob[3][:10]))
print ("\nMost common fourgrams: ", str(ngrams_prob[4][:10]))
# Out:
# Most common n-grams without stopword removal and with add-1 smoothing:
#
# Most common unigrams:  [[('<UNK>',), 0.12918531362028163], [('A_detail_request',), 0.09350470957613814], [('U_answer',), 0.08446191335317135], [('U_sequence_closer',), 0.08422760608261674], [('A_greeting',), 0.07811950842334638], [('A_sequence_closer',), 0.06953361137796106], [('U_confirmation',), 0.06925976475550036], [('A_confirmation',), 0.06890098174746362], [('U_partial_request',), 0.06879847231659598], [('A_grant',), 0.06227155041120926]]
#
# Most common bigrams:  [[('A_confirmation', 'A_sequence_closer'), 0.042966175117006435], [('A_detail_request', 'U_answer'), 0.04189408533774582], [('<UNK>', '<UNK>'), 0.04128897023824718], [('U_confirmation', 'U_sequence_closer'), 0.04007123240774247], [('U_partial_request', 'A_grant'), 0.028276743309574182], [('A_greeting', 'A_detail_request'), 0.026013943173235594], [('<s>', '<ss>'), 0.02595988822638212], [('<ee>', '<e>'), 0.02595988822638212], [('U_answer', 'A_confirmation'), 0.02397487045581834], [('U_greeting', 'U_partial_request'), 0.02162348026769211]]
#
# Most common trigrams:  [[('U_answer', 'A_confirmation', 'A_sequence_closer'), 0.018695486830967774], [('A_confirmation', 'A_sequence_closer', 'A_detail_request'), 0.016346283597286456], [('<UNK>', '<UNK>', '<UNK>'), 0.016303347767950244], [('<s>', '<ss>', 'A_greeting'), 0.015570371824282052], [('A_detail_request', 'U_confirmation', 'U_answer'), 0.014526111117926323], [('A_detail_request', 'U_answer', 'A_confirmation'), 0.014523044272973736], [('A_grant', 'U_confirmation', 'U_sequence_closer'), 0.014090619134659027], [('A_detail_request', 'U_greeting', 'U_answer'), 0.012756541580283868], [('U_partial_request', 'A_greeting', 'A_grant'), 0.012350184624066146], [('<UNK>', 'U_confirmation', 'U_sequence_closer'), 0.01232411644196916]]
#
# Most common fourgrams:  [[('A_detail_request', 'U_answer', 'A_confirmation', 'A_sequence_closer'), 0.011869084505849885], [('A_confirmation', 'A_sequence_closer', 'A_detail_request', 'U_answer'), 0.009189266567231721], [('U_partial_request', 'A_grant', 'U_confirmation', 'U_sequence_closer'), 0.007988658875030592], [('U_answer', 'A_confirmation', 'A_sequence_closer', 'A_detail_request'), 0.007907079121586157], [('A_greeting', 'A_detail_request', 'U_greeting', 'U_answer'), 0.0076284765673702536], [('<UNK>', '<UNK>', '<UNK>', '<UNK>'), 0.007580760107808414], [('<s>', '<ss>', 'A_greeting', 'A_detail_request'), 0.0070789676620935825], [('U_greeting', 'U_partial_request', 'A_greeting', 'A_grant'), 0.006764962573364057], [('A_detail_request', 'U_answer', 'A_detail_request', 'U_answer'), 0.006324739752890309], [('<s>', '<ss>', 'A_greeting', 'A_greeting'), 0.006175433411680682]]

# %% [markdown]
# ### To calculate probability of unseen sequences

# %%
def ngram_prediction(tokenized_sent):
    ngram = {1:[], 2:[], 3:[]}#to store n-grams formed from the strings

    for i in range(1, 4):
        ngram[i] = list(ngrams(tokenized_sent, i))[-1]
    
    print("String: ", ngram)
    
    for j in range(4):
        ngrams_prob[j+1] = sorted(ngrams_prob[j+1], key = lambda x:x[1], reverse = True)
    
    pred = {1:[], 2:[], 3:[]}
    for k in range(3):
        count = 0
        for each in ngrams_prob[k+2]:
            if each[0][:-1] == ngram[k+1]:#to find predictions based on highest probability of n-grams                   
                count +=1
                pred[k+1].append(each[0][-1])
                if count ==5:
                    break
        if count<5:
            while(count!=5):
                pred[k+1].append("NA")#if no word prediction is found, replace with NOT FOUND
                count +=1
                
    return pred, ngrams_prob

token_1 = ['<s>','U_greeting','<UNK>','A_greeting','A_confirmation']
token_2 = ['<s>','U_greeting','A_greeting']
pred_1, ngrams_prob_1 = ngram_prediction(token_1)
pred_2, ngrams_prob_2 = ngram_prediction(token_2)
# Out:
# String:  {1: ('A_confirmation',), 2: ('A_greeting', 'A_confirmation'), 3: ('<UNK>', 'A_greeting', 'A_confirmation')}
# String:  {1: ('A_greeting',), 2: ('U_greeting', 'A_greeting'), 3: ('<s>', 'U_greeting', 'A_greeting')}

# %%
print("Next word predictions for the strings using the probability models of bigrams, trigrams, and fourgrams\n")
print("String 1 \n")
print("Bigram model predictions: {}\nTrigram model predictions: {}\nFourgram model predictions: {}\n" .format(pred_1[1], pred_1[2], pred_1[3]))
print("String 2 \n")
print("Bigram model predictions: {}\nTrigram model predictions: {}\nFourgram model predictions: {}" .format(pred_2[1], pred_2[2], pred_2[3]))
# Out:
# Next word predictions for the strings using the probability models of bigrams, trigrams, and fourgrams
#
# String 1
#
# Bigram model predictions: ['A_sequence_closer', 'A_grant', 'A_detail_request', '<UNK>', 'U_confirmation']
# Trigram model predictions: ['A_sequence_closer', 'A_grant', 'A_detail_request', 'A_completion_check', '<UNK>']
# Fourgram model predictions: ['A_sequence_closer', 'A_detail_request', 'A_completion_check', '<UNK>', 'U_confirmation']
#
# String 2
#
# Bigram model predictions: ['A_detail_request', 'A_grant', 'A_confirmation', 'A_greeting', 'A_completion_check']
# Trigram model predictions: ['A_detail_request', 'A_confirmation', 'A_greeting', '<UNK>', 'U_greeting']
# Fourgram model predictions: ['NA', 'NA', 'NA', 'NA', 'NA']

# %%
#Dict of probabilities from unigram to fourgram

# ngrams_prob

# %% [markdown]
# ### Perplexity
# An intrinsic evaluation metric is one that measures the quality of a model independent of any application.
#
# The perplexity of a language model on a test set is the inverse probability of the test set, normalized by the number of words. Thus the higher the conditional probability of the word sequence, the lower the perplexity, and maximizing the perplexity is equivalent to maximizing the test set probability according to the language model.
#
# https://stackoverflow.com/questions/54941966/how-can-i-calculate-perplexity-using-nltk/55043954#55043954?newreg=b97aa34187184c90988f9a75e51898c2
#
# ##### Here we calculate perprexity in the whole dataset. without train, dev, test. Why though??
# Maybe because it's unsupervised??
# i've read about v/k folding. also seems to need x and y

# %%
print(len(unigram))
# Out:
# 17289

# %%
import nltk
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE
from nltk.lm import Vocabulary

unigram_train = unigram[0:17000]

n = 2
train_data = [nltk.bigrams(t,  pad_right=True, pad_left=True, left_pad_symbol="<s>", right_pad_symbol="<e>") for t in unigram_train]
words = [word for sent in unigram_train for word in sent]
words.extend(["<s>", "<e>"])
padded_vocab = Vocabulary(words)
model = MLE(n)
model.fit(train_data, padded_vocab)

unigram_test = unigram[17000:] # if you want to test just small sample
print(len(unigram_test))

test_data = [nltk.bigrams(t,  pad_right=True, pad_left=True, left_pad_symbol="<s>", right_pad_symbol="<e>") for t in unigram_test]

#for each bigram MLE estimate (tuples estimate)
#maximizing a likelihood function so that, under the assumed statistical model, the observed data is most probable.
#if you don't want to see MLE per tuple comment print line

for test in test_data:
#     print ("MLE Estimates:", [((ngram[-1], ngram[:-1]),model.score(ngram[-1], ngram[:-1])) for ngram in test]) # will generate one estimator per input. Here each input contains all DA labels for one dialog sequence.
    pass

#for whole dialog perplexity calculation.
#if print unigram_test[i] you see sentence and perplexity. 
#to make it easier to read perplexities (not caring about the specific sentence) print second line (only i)

test_data = [nltk.bigrams(t,  pad_right=True, pad_left=True, left_pad_symbol="<s>", right_pad_symbol="<e>") for t in unigram_test]

for i, test in enumerate(test_data):
#     print("PP({0}):{1}".format(unigram_test[i], model.perplexity(test)))
    print("PP({0}):{1}".format(i, model.perplexity(test)))
# Out:
# 289
# PP(0):4.495144982893566
# PP(1):6.326616659124132
# PP(2):5.497682392981005
# PP(3):5.75324874562967
# PP(4):5.412144654668064
# PP(5):4.529008613318499
# PP(6):4.180794405334284
# PP(7):5.2581944340617826
# PP(8):5.08739754205226
# PP(9):6.011258447507772
# PP(10):7.6716667135807075
# PP(11):6.089039511106873
# PP(12):5.7559805622349955
# PP(13):4.246438130101796
# PP(14):5.372605240203295
# PP(15):3.8863468625452278
# PP(16):4.180711472490924
# PP(17):5.107190378495074
# PP(18):5.995346154355288
# PP(19):7.417165309837154
# PP(20):4.3063066521824895
# PP(21):4.31752606891241
# PP(22):5.224650106896126
# PP(23):3.9139436007820816
# PP(24):4.770950276259043
# PP(25):4.646804835196973
# PP(26):5.130569452790832
# PP(27):5.0718929856778185
# PP(28):5.350757978164802
# PP(29):5.516711860489342
# PP(30):4.792476553398838
# PP(31):5.093554370823045
# PP(32):5.50690398840427
# PP(33):4.486775876468721
# PP(34):5.655286798517427
# PP(35):4.327048160207561
# PP(36):3.5013216630540036
# PP(37):5.009321705869809
# PP(38):5.462687492048554
# PP(39):4.937509135793148
# PP(40):4.306517306875532
# PP(41):4.46323332972117
# PP(42):4.485230851360845
# PP(43):3.9348508960110173
# PP(44):4.651317523803883
# PP(45):4.091357322830243
# PP(46):5.115460622177108
# PP(47):4.603985580954422
# PP(48):3.529213956883075
# PP(49):4.59725791437004
# PP(50):3.816444089359139
# PP(51):4.665331540862503
# PP(52):5.260803418314771
# PP(53):5.729493789465825
# PP(54):5.092886167073118
# PP(55):4.450760773304797
# PP(56):4.566364912405986
# PP(57):4.147694698826343
# PP(58):5.8757716970181075
# PP(59):5.756114880766092
# PP(60):4.587041146004869
# PP(61):4.444083823049555
# PP(62):5.281911094612221
# PP(63):5.231436047718654
# PP(64):4.820859873998673
# PP(65):5.265759258059544
# PP(66):4.188634717374588
# PP(67):4.713645768600945
# PP(68):3.688154350912083
# PP(69):5.778931187995376
# PP(70):4.435993407796234
# PP(71):4.418968367245633
# PP(72):4.772377833264792
# PP(73):5.807513211826781
# PP(74):6.00916434742079
# PP(75):4.977163040211347
# PP(76):4.324905124237871
# PP(77):4.895454366477151
# PP(78):4.937090663675733
# PP(79):4.163068670810629
# PP(80):4.7583186495053225
# PP(81):3.848607360657517
# PP(82):4.4148935628725425
# PP(83):5.052033005952869
# PP(84):3.9421243536655184
# PP(85):3.626634929606158
# PP(86):4.286486924588066
# PP(87):7.097703471045774
# PP(88):6.79698443721966
# PP(89):4.610484740688254
# PP(90):7.5523505907668715
# PP(91):4.5408997911479
# PP(92):4.57430663271709
# PP(93):4.4176280763957285
# PP(94):4.494481016470814
# PP(95):4.504082722591821
# PP(96):4.584089871747082
# PP(97):5.835860457624274
# PP(98):4.38512901854392
# PP(99):3.8492680589925747
# PP(100):4.447298627089716
# PP(101):6.398018174721362
# PP(102):5.746686447350874
# PP(103):4.3647481418093905
# PP(104):5.126833710379823
# PP(105):4.240766798659942
# PP(106):6.054630395602091
# PP(107):5.131521013871941
# PP(108):3.541986716814061
# PP(109):5.439309670243715
# PP(110):7.753701628760164
# PP(111):4.627602918901564
# PP(112):5.5662947823195745
# PP(113):5.359748065052421
# PP(114):6.159143960639843
# PP(115):5.220983943673545
# PP(116):4.252188331981486
# PP(117):5.190040516105042
# PP(118):3.9127826382126036
# PP(119):5.592004937726033
# PP(120):4.2024498971127375
# PP(121):4.436596052085099
# PP(122):4.676061044108794
# PP(123):5.022817713230595
# PP(124):4.3244609704117964
# PP(125):6.25628496328318
# PP(126):4.895122807517753
# PP(127):4.35373114336494
# PP(128):7.191877690810076
# PP(129):5.701786558297049
# PP(130):6.115424824055779
# PP(131):4.5522799751731275
# PP(132):4.912950968054524
# PP(133):6.984955722615997
# PP(134):4.347033566295904
# PP(135):5.234964865518515
# PP(136):5.186738594131179
# PP(137):4.708406060264584
# PP(138):4.6268995626562885
# PP(139):4.993026096517622
# PP(140):4.254562915009853
# PP(141):4.813475892768235
# PP(142):6.263394637845613
# PP(143):5.55945206973864
# PP(144):5.214279401686858
# PP(145):4.599760682226419
# PP(146):4.494510937179126
# PP(147):4.933838355539425
# PP(148):5.599021672620207
# PP(149):4.219496309871267
# PP(150):4.5025201975927285
# PP(151):4.491326943493121
# PP(152):4.742332712886444
# PP(153):4.624903075953691
# PP(154):5.0420840969180425
# PP(155):6.566498206744648
# PP(156):4.7968527251080895
# PP(157):5.265483134374191
# PP(158):4.967642312918355
# PP(159):3.929480834243398
# PP(160):4.613131635359229
# PP(161):4.6838385551132085
# PP(162):4.948249198245323
# PP(163):3.741059883661762
# PP(164):5.844490441968334
# PP(165):4.226090481217285
# PP(166):4.929976479186006
# PP(167):5.961525002242212
# PP(168):4.852036933299347
# PP(169):5.143800549104746
# PP(170):3.8599795078547636
# PP(171):4.773859438502263
# PP(172):6.04398128957529
# PP(173):7.5133676812614
# PP(174):4.7054944431345405
# PP(175):5.0114695691608375
# PP(176):4.343146432966856
# PP(177):5.632638188276035
# PP(178):5.547236027626531
# PP(179):4.254716861404038
# PP(180):5.339836548398705
# PP(181):4.759258173009568
# PP(182):4.199624058104696
# PP(183):3.7594805042980024
# PP(184):4.544472086453534
# PP(185):5.3587703899380985
# PP(186):4.583646337420654
# PP(187):4.692193555880948
# PP(188):3.9152184724684553
# PP(189):7.016529975344546
# PP(190):4.58106844767284
# PP(191):6.060968707075119
# PP(192):5.305463867325779
# PP(193):4.821571592465834
# PP(194):4.367713170738881
# PP(195):4.532668698713121
# PP(196):4.544096131070125
# PP(197):4.122873279825459
# PP(198):5.369033146024404
# PP(199):4.494139411939508
# PP(200):4.897987884407191
# PP(201):4.408935307651141
# PP(202):5.5476079666538505
# PP(203):5.952547717495629
# PP(204):4.210916184439981
# PP(205):6.20301679046644
# PP(206):4.274649720764746
# PP(207):4.328231207155527
# PP(208):4.996541666042656
# PP(209):4.7665869042051785
# PP(210):6.245249237304773
# PP(211):5.952392136508519
# PP(212):4.425952003981211
# PP(213):4.432643402031012
# PP(214):4.177526948816939
# PP(215):5.181670118009847
# PP(216):4.165051887358761
# PP(217):4.2910481880366484
# PP(218):4.588767622397069
# PP(219):5.088357376390233
# PP(220):4.405550585137946
# PP(221):5.46556726888519
# PP(222):5.260876170519008
# PP(223):4.93855016193605
# PP(224):4.945458827764492
# PP(225):4.092395752651997
# PP(226):5.223824292415344
# PP(227):5.367347144925782
# PP(228):5.649887124086677
# PP(229):5.881438473617668
# PP(230):5.48856300352949
# PP(231):4.446132474970929
# PP(232):4.337501538323179
# PP(233):5.209730651348787
# PP(234):7.604022755035453
# PP(235):5.492794140559385
# PP(236):4.919407877572411
# PP(237):3.738647147169444
# PP(238):4.858793686691606
# PP(239):6.830747253452151
# PP(240):4.809437146316157
# PP(241):5.026885357817915
# PP(242):4.195202231588268
# PP(243):4.400642616203435
# PP(244):5.064298350650415
# PP(245):6.889669230418935
# PP(246):6.042827987098275
# PP(247):5.601144183021851
# PP(248):4.896579014474754
# PP(249):3.9145755975488923
# PP(250):3.8811436219504034
# PP(251):4.606479931168892
# PP(252):4.541732538860433
# PP(253):4.083498953475557
# PP(254):5.116011284105703
# PP(255):9.508583264170998
# PP(256):5.6682789657410035
# PP(257):4.9723309951359145
# PP(258):4.474955538231097
# PP(259):5.336424197969399
# PP(260):3.8507592579680856
# PP(261):3.9234627767760744
# PP(262):4.914683246075116
# PP(263):4.43248906622409
# PP(264):4.37192233722126
# PP(265):3.6748502135938637
# PP(266):9.117630967772847
# PP(267):4.597346880369814
# PP(268):3.4725646343103755
# PP(269):7.511267311290798
# PP(270):4.568894280236302
# PP(271):5.015626431457982
# PP(272):4.610287838677596
# PP(273):5.079200141247483
# PP(274):4.927620881046546
# PP(275):6.151725497198228
# PP(276):5.2990913764382706
# PP(277):5.848329120287238
# PP(278):5.141362414165016
# PP(279):5.407871791552717
# PP(280):5.089575984419348
# PP(281):4.33474392468311
# PP(282):5.4751902599304305
# PP(283):5.077180058611944
# PP(284):3.5285197851556416
# PP(285):4.846057639228473
# PP(286):3.9338522628622727
# PP(287):5.260599383969246
# PP(288):5.734661897731338

# %%
uni = {}
bi = {}
tri = {}
four = {}

######## this alternative version makes some parts of the code not to work for bi,tri,four.

for key, value in ngrams_prob.items():
    for lista in value:
#         lista[0] = str(lista[0])
#         lista[0] = re.sub(r"['(),]", "", lista[0])
        
        if key ==1:
            lista[0] = str(lista[0])
            lista[0] = re.sub(r"['(),]", "", lista[0])
            uni[lista[0]] = lista[1]
        if key ==2:
            bi[lista[0]] = lista[1]
        if key ==3:
            tri[lista[0]] = lista[1]
        if key ==4:
            four[lista[0]] = lista[1]

# %% [markdown]
# ### Make emission probabilities for hidden state New
#
# - use shift(1) por exemplo
# - count +=1 for that combination of 2 labels every time one label is followed by next.
# - I want to calculate for t, the p(t|t+1) for bigrams and p(t|t+1)*p(t+1|t+2)
# - format:
#     - bi: {('A_confirmation', 'A_sequence_closer'): 0.042966175117006435,
#     - tri: {('U_answer', 'A_confirmation', 'A_sequence_closer'): 0.018695486830967774,

# %%
# unique da counting special symbols
da_u = [] #uni.keys()
[da_u.append(k) for k in uni.keys()]

#create shifted DA for future bigram
df['shifted_DA_bi'] = df['all_DA'].shift(-1)

#create shifted DA for future trigram
df['shifted_DA_tri'] = df['all_DA'].shift(-2)
df.head()
# Out:
#       task                           conversation_id instruction_id  index  \
# 0  flights  dlg-00100680-00e0-40fe-8321-6d81b21bfc4f      flight-12      0
# 1  flights  dlg-00100680-00e0-40fe-8321-6d81b21bfc4f      flight-12      0
# 2  flights  dlg-00100680-00e0-40fe-8321-6d81b21bfc4f      flight-12      1
# 2  flights  dlg-00100680-00e0-40fe-8321-6d81b21bfc4f      flight-12      1
# 3  flights  dlg-00100680-00e0-40fe-8321-6d81b21bfc4f      flight-12      2
#
#   speaker                                               text  \
# 0       U  Hello. I'd like to find a round trip commercia...
# 1       U  Hello. I'd like to find a round trip commercia...
# 2       A                         Hello, how can I help you?
# 2       A                         Hello, how can I help you?
# 3       A                   San Francisco to Denver, got it.
#
#                                             segments  \
# 0  [{'start_index': 26, 'end_index': 36, 'text': ...
# 1  [{'start_index': 26, 'end_index': 36, 'text': ...
# 2                                                NaN
# 2                                                NaN
# 3  [{'start_index': 0, 'end_index': 13, 'text': '...
#
#                                             new_text            all_DA  \
# 0                                             Hello.        U_greeting
# 1  I'd like to find a round trip commercial airli...             <UNK>
# 2                         Hello, how can I help you?        A_greeting
# 2                         Hello, how can I help you?  A_detail_request
# 3                   San Francisco to Denver, got it.    A_confirmation
#
#       shifted_DA_bi    shifted_DA_tri
# 0             <UNK>        A_greeting
# 1        A_greeting  A_detail_request
# 2  A_detail_request    A_confirmation
# 2    A_confirmation        U_greeting
# 3        U_greeting             <UNK>

# %%
#count occurrences of each DA

df = df.reset_index(drop=True)
count_DA = df['all_DA'].value_counts().reset_index(name='Counts')
count_DA.iloc[0, 0]
count_da = {}
for e in range(len(count_DA)):
    count_da[count_DA.iloc[e, 0]] = count_DA.iloc[e, 1]

count_da

#create list of all possible unique bigrams and trigrams. order matters

da_tuples = []

for fir in range(len(da_u)):
    for sec in range(len(da_u)):
        da_tuples.append((da_u[fir], da_u[sec]))


da_triples = []

for fir in range(len(da_u)):
    for sec in range(len(da_u)):
        for thir in range(len(da_u)):
            da_triples.append((da_u[fir],da_u[sec], da_u[thir]))


#sanity check bi and tri
print(len(da_tuples) == len(da_u)*len(da_u), len(da_tuples))
print(len(da_triples) == len(da_u)**3, len(da_triples))



#count occurrences for bigrams
bi_next = {}

for row in range(len(df)-1):
    k = (df['all_DA'][row], df['shifted_DA_bi'][row])            
    bi_next[k] = bi_next[k] + 1 if k in bi_next else 1
    
bi_next

#count occurrences for trigrams
tri_next = {}

for row in range(len(df)-1):
    k = (df['all_DA'][row], df['shifted_DA_bi'][row], df['shifted_DA_tri'][row])            
    tri_next[k] = tri_next[k] + 1 if k in tri_next else 1
    
# tri_next
# Out:
# True 729
# True 19683

# %% [markdown]
# ## Correct past bi/trigrams (including all possible examples, now it has only non zero examples)

# %%
# bi_past same as bi, but if there is no match prob will be set to 0.00000000000001 or sth very low
#same has to be done for tri_past and tri

bi_past = {} #use da_tuples list ad basis, since contains all possibilities
tri_past = {} #use da_triples list ad basis, since contains all possibilities
          
for dupla in da_tuples: #list containing all possible tuples of bigram
    bi_past[dupla] = 0.0000000001 
    for k in bi.keys():
        if k == dupla:
            bi_past[dupla] = bi.get(k)
            
for tripla in da_triples: #list containing all possible tuples of bigram
    tri_past[tripla] = 0.0000000001 
    for ka in tri.keys():
        if ka == tripla:
            tri_past[tripla] = tri.get(ka)

#sanity check
print(len(bi_past) == len(da_u)**2, len(bi_past))
print(len(tri_past) == len(da_u)**3, len(tri_past))
# Out:
# True 729
# True 19683

# %% [markdown]
# ## Future bi/trigrams

# %%
bi_fut = {}
for A in da_u:
    for B in da_u:
        bi_fut[(A,B)] = bi_past.get((A,B))*uni.get(A)/uni.get(B)
        
tri_fut = {}
for e, A in enumerate(da_u):
    for f, B in enumerate(da_u):
        for g, C in enumerate(da_u):
            tri_fut[(A,B,C)] = tri_past.get((A,B,C))*bi_past.get((A,C))/bi_past.get((B,C))

#sanity check
print(len(bi_fut) == len(bi_past))
print(len(tri_fut) == len(tri_past))
# Out:
# True
# True

# %% [markdown]
# ## HMM
#
# from wikipedia, code inclusive: https://en.wikipedia.org/wiki/Viterbi_algorithm#Pseudocode

# %%
###### TRIGRAMS
######PS: this would need as input sentences with padding=2 (each side)

def viterbi(obs, states, start_p, trans_p, emit_p, emit_p_bi, emit_p_tri): 
    V = [{}]

    for st in states:
        V[0] [st] = {"prob": start_p[st] * emit_p[st] [obs[0]], "prev": None} #### OLD
        V.append({})
        V[1] [st] = {"prob": start_p[st] * emit_p[st] [obs[1]], "prev": None} #### NEW


    # Run Viterbi when t > 1
    for t in range(2, len(obs)-2): #in my example len(obs)=32. i.e: range 2, 31 inclusive
        V.append({})
        for st in states: #New and Current            
            max_tr_prob = V[t - 1] [states[0]] ["prob"] * trans_p[states[0]] [st] #0.026402178674778336*0.1 and same*0.9 ######### NEW
            prev_st_selected = states[0] 
            
            for prev_st in states[1:]: #(states[1:]) >>> Current
                tr_prob = V[t - 1] [prev_st] ["prob"] * trans_p[prev_st] [st] # a diferenca aqui em relacao ao max_tr_prob é que aqui se calcula o previous state
                if tr_prob > max_tr_prob: #if other state is higher than state 0 (i.e if Current > New)
                    max_tr_prob = tr_prob #then new max is Current instead on New. Here we store the actual probability
                    prev_st_selected = prev_st #and previous state is updated. Here we store name of state

            ######################################## includes emit_p for trigram,bigram and unigram
            
            # max_prob = max_tr_prob * statistics.fmean([emit_p[st] [obs[t]],emit_p_bi[state].get((obs[t-1],obs[t])), emit_p_tri[state].get((obs[t-2],obs[t-1],obs[t]))]) 

            ####################################### includes emit_p for trigram,bigram and unigram if new and if current
            if st == 'New':
                max_prob = max_tr_prob * statistics.fmean([emit_p[st] [obs[t]], emit_p_bi[st].get((obs[t],obs[t+1])), emit_p_tri[st].get((obs[t],obs[t+1],obs[t+2]))]) 
            elif st == 'Current':
                max_prob = max_tr_prob * statistics.fmean([emit_p[st] [obs[t]], emit_p_bi[st].get((obs[t-1],obs[t])), emit_p_tri[st].get((obs[t-2],obs[t-1],obs[t]))]) 
            
            
            V[t] [st] = {"prob": max_prob, "prev": prev_st_selected}

    V = V[:-1]
#     for line in dptable(V):
#         print(line)

    optimal = []
    max_prob = 0.0
    best_st = None
    
    # Get most probable state and its backtrack
    for st, data in V[-1].items(): # V[-1] is the last dic. ex: {'New': {'prob': 6.983898154776834e-19, 'prev': 'Current'}, 'Current': {'prob': 1.5713770848247866e-18, 'prev': 'New'}
        if data["prob"] > max_prob: #6.983898154776834e-19 > 0.0 (in first step)
            max_prob = data["prob"] #update max prob to compare with second state in next iteration
            best_st = st
    optimal.append(best_st) #appending all best states
    previous = best_st #updating previous as best state to be used later


    # Follow the backtrack till the first observation
    for t in range(len(V) - 2, -1, -1): # start=len(V)-2, stop=-1, step=-1. Calculates from last step to first ###### NEW
        optimal.insert(0, V[t + 1] [previous] ["prev"])
        previous = V[t + 1] [previous] ["prev"]
    optimal = optimal[1:]
    
#     print ("The steps of states are " + " ".join(optimal) + " with highest probability of %s" % max_prob)
    return optimal, max_prob

def dptable(V):
    # Print a table of steps from dictionary
    yield " " * 5 + "     ".join(("%3d" % i) for i in range(len(V)))
    for state in V[0]:
        yield "%.7s: " % state + " ".join("%.7s" % ("%lf" % v[state] ["prob"]) for v in V)

# %%
#trigrams add slighly more current sequences. with unigrams no sequences, always cycle [New,Current,New,Current...]
obs = unigram[3] # just an example
states = ['New', 'Current']
start_p = {'New':0.9999,'Current':0.0001}

Cur = 0.6+1e-70
Ne = 1 - Cur

trans_p = {'New': {'New':0.1,'Current':0.9}, 'Current': {'New': Ne,'Current':Cur}} #the higher current, more it appears. 0.6 too litle, 0.7 too much
emit_uni = {}
emit_bi = {}
emit_tri = {}

emit_uni['New'] = uni
emit_uni['Current'] = uni 
emit_bi['New'] = bi_fut 
emit_bi['Current'] = bi_past 
emit_tri['New'] = tri_fut 
emit_tri['Current'] = tri_past 

seq, pro = viterbi(obs, states, start_p, trans_p, emit_uni, emit_bi, emit_tri) #steps are being rounded to zero cause prob is much smaller. Final is around e-18

# %% [markdown]
# ## Statistics with whole dataset

# %%
# depois mapping unigram[i]:hmm_seq[i]

#call function for all dialogues with repair initiator. save in dict in which key=dialogue id and value=paraphrase  
    
hmm_seq = []
count =0
for dialog in unigram:
    try:
        seq, p = viterbi(dialog, states, start_p, trans_p, emit_uni, emit_bi, emit_tri)
        hmm_seq.append([dialog[2:-1], seq, p]) #remove extra symbols from dialog (<s>, <ss>, <e>)
    except Exception:
        count+=1
        pass

print(len(hmm_seq))
print(count)
# Out:
# 17288
# 1

# %%
# printing examples

print(len(hmm_seq[2][0]))
print(len(hmm_seq[2][1]))
print(hmm_seq[2][0])
print(hmm_seq[2][1])


#is it two less in begin and 1 in the end or both is the beginning
# insert None, None in begining and one None in the end
# Out:
# ['<s>', '<ss>', 'U_greeting', '<UNK>', 'A_greeting', 'A_detail_request', 'A_confirmation', 'A_detail_request', 'U_answer', 'A_detail_request', 'U_answer', 'A_detail_request', 'U_answer', 'A_greeting', 'A_completion_check', 'A_detail_request', 'U_greeting', 'U_answer', '<UNK>', 'U_confirmation', 'U_sequence_closer', 'U_partial_request', 'A_confirmation', 'A_grant', 'U_partial_request', 'A_greeting', 'A_grant', 'U_confirmation', 'U_sequence_closer', '<UNK>', 'U_sequence_closer', 'A_greeting', 'A_confirmation', 'A_completion_check', 'A_detail_request', 'U_greeting', 'U_answer', '<UNK>', '<UNK>', '<ee>', '<e>']
# 38
# 38
# ['U_greeting', '<UNK>', 'A_greeting', 'A_detail_request', 'A_confirmation', 'A_detail_request', 'U_answer', 'A_detail_request', 'U_answer', 'A_detail_request', 'U_answer', 'A_greeting', 'A_completion_check', 'A_detail_request', 'U_greeting', 'U_answer', '<UNK>', 'U_confirmation', 'U_sequence_closer', 'U_partial_request', 'A_confirmation', 'A_grant', 'U_partial_request', 'A_greeting', 'A_grant', 'U_confirmation', 'U_sequence_closer', '<UNK>', 'U_sequence_closer', 'A_greeting', 'A_confirmation', 'A_completion_check', 'A_detail_request', 'U_greeting', 'U_answer', '<UNK>', '<UNK>', '<ee>']
# ['New', 'Current', 'Current', 'New', 'Current', 'Current', 'New', 'Current', 'New', 'Current', 'New', 'Current', 'New', 'Current', 'New', 'Current', 'Current', 'Current', 'New', 'Current', 'New', 'Current', 'Current', 'New', 'Current', 'Current', 'New', 'Current', 'Current', 'Current', 'New', 'Current', 'Current', 'New', 'Current', 'Current', 'New', 'Current']

# %%
from more_itertools import locate

all_da_seq = []
all_hid_seq = []
count = 0

for e, i_ in enumerate(hmm_seq):
    s_da = hmm_seq[e][0]
    s_hid = hmm_seq[e][1]
    
    if len(s_da)==len(s_hid): #sanity check that all contain same len
        #https://thispointer.com/python-how-to-find-all-indexes-of-an-item-in-a-list/
        index_new = list(locate(s_hid, lambda a: a == 'New')) 
        #https://www.geeksforgeeks.org/python-custom-list-split/?ref=lbp 
        split_hidden_lab = [s_hid[i : j] for i, j in zip([0] +  index_new, index_new + [None])]
        split_da_lab = [s_da[i : j] for i, j in zip([0] +  index_new, index_new + [None])]

        all_hid_seq.append(split_hidden_lab)
        all_da_seq.append(split_da_lab)
    else: count+=1

all_hid_seq
all_da_seq
# Out:
# [[[],
#   ['U_greeting', '<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_confirmation', 'U_greeting', '<UNK>'],
#   ['A_detail_request', 'A_greeting'],
#   ['A_detail_request', 'U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation', 'A_detail_request', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>', 'A_request_summary', 'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_sequence_closer', '<UNK>'],
#   ['U_partial_request', 'A_detail_request'],
#   ['A_grant', 'U_answer'],
#   ['A_confirmation', 'A_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer',
#    'U_sequence_closer',
#    'U_sequence_closer',
#    'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer', '<UNK>'],
#   ['U_greeting', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['A_greeting', 'A_confirmation', '<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer', 'A_confirmation', '<UNK>'],
#   ['A_greeting', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_sequence_closer', 'A_greeting'],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer',
#    '<UNK>',
#    'U_sequence_closer',
#    'A_greeting',
#    'U_confirmation',
#    'A_sequence_closer',
#    '<UNK>'],
#   ['<UNK>', 'U_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', 'U_partial_request'],
#   ['A_greeting', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_sequence_closer', 'A_greeting'],
#   ['A_confirmation', 'A_completion_check', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>'],
#   ['<UNK>', '<ee>']],
#  [[],
#   ['U_greeting', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'U_greeting', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_greeting', 'U_sequence_closer'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_disconfirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_disconfirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_sequence_closer'],
#   ['A_disconfirmation', '<UNK>'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'U_greeting'],
#   ['U_partial_request', 'A_grant', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', 'U_sequence_closer'],
#   ['A_sequence_closer', 'A_receipt', '<UNK>', 'U_partial_request'],
#   ['A_grant', '<UNK>', 'A_sequence_closer'],
#   ['U_receipt', 'U_sequence_closer'],
#   ['<UNK>', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', 'A_confirmation', '<UNK>', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'U_partial_request'],
#   ['A_greeting', 'A_grant', 'A_greeting'],
#   ['A_detail_request', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'U_confirmation'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_confirmation', '<UNK>'],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_disconfirmation', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', 'A_detail_request'],
#   ['U_partial_request', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_grant', 'A_detail_request', '<UNK>', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_partial_request', 'U_answer'],
#   ['<UNK>', 'A_disconfirmation', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer'],
#   ['A_confirmation', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_disconfirmation', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', 'A_confirmation', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['A_confirmation', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['A_greeting', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'U_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_partial_request'],
#   ['U_answer', 'A_detail_request'],
#   ['A_grant', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_hold_request', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_partial_request'],
#   ['A_greeting', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>'],
#   ['<UNK>', 'U_greeting', 'A_repair_initiator', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_hold_request', 'U_sequence_closer', '<UNK>'],
#   ['U_confirmation', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_partial_request'],
#   ['U_answer', 'A_grant', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_greeting'],
#   ['U_partial_request', 'A_greeting', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting', 'U_confirmation', 'A_greeting'],
#   ['U_confirmation', 'U_confirmation', 'A_sequence_closer'],
#   ['A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer'],
#   ['<UNK>', 'A_receipt', 'A_sequence_closer'],
#   ['A_sequence_closer', 'A_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer'],
#   ['A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'A_greeting'],
#   ['A_confirmation', 'U_sequence_closer'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer',
#    'A_request_summary',
#    'A_confirmation',
#    'A_detail_request'],
#   ['U_request_summary', 'U_confirmation'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer',
#    'A_hold_request',
#    'A_hold_request',
#    'A_greeting',
#    'U_sequence_closer',
#    'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', 'A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'U_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'A_greeting'],
#   ['A_detail_request', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_confirmation'],
#   ['U_sequence_closer', 'A_detail_request'],
#   ['U_answer',
#    'A_detail_request',
#    'U_confirmation',
#    'U_disconfirmation',
#    'U_answer'],
#   ['A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', 'A_greeting', 'U_sequence_closer'],
#   ['U_partial_request', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer',
#    '<UNK>',
#    'U_sequence_closer',
#    'A_sequence_closer',
#    '<UNK>',
#    'A_receipt',
#    'U_sequence_closer',
#    '<ee>']],
#  [[],
#   ['U_greeting', 'A_greeting'],
#   ['A_detail_request', 'A_greeting'],
#   ['A_detail_request', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_partial_request', '<UNK>'],
#   ['A_sequence_closer', 'U_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'U_greeting', 'U_greeting'],
#   ['U_partial_request', 'U_greeting'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_hold_request', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request', 'U_greeting', 'U_partial_request'],
#   ['U_answer', 'A_grant', '<UNK>'],
#   ['A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_confirmation', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer',
#    'U_sequence_closer',
#    'A_confirmation',
#    'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_hold_request', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_greeting', 'U_confirmation'],
#   ['U_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_greeting'],
#   ['A_confirmation', 'A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'U_greeting'],
#   ['U_partial_request', 'A_confirmation'],
#   ['A_grant', 'A_hold_request', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_greeting'],
#   ['A_confirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation', 'A_greeting', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_repair_initiator', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_greeting', 'U_sequence_closer'],
#   ['U_answer', 'A_greeting'],
#   ['A_detail_request', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_partial_request'],
#   ['U_answer', 'A_detail_request'],
#   ['A_grant', 'U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_partial_request', 'U_answer'],
#   ['A_confirmation',
#    'A_grant',
#    '<UNK>',
#    'A_completion_check',
#    'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', 'U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer'],
#   ['U_confirmation', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_detail_request', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['A_request_summary', 'A_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['A_greeting', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_confirmation', 'A_completion_check', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', '<UNK>'],
#   ['<UNK>', 'A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>'],
#   ['<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_greeting'],
#   ['A_confirmation', 'A_request_summary', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_partial_request', 'U_partial_request'],
#   ['A_grant', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_partial_request', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'A_grant', 'U_sequence_closer'],
#   ['U_answer', 'A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'U_sequence_closer'],
#   ['A_receipt', '<UNK>', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_answer',
#    'A_confirmation',
#    'A_request_summary',
#    'U_confirmation',
#    'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', 'U_partial_request'],
#   ['A_grant', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting',
#    'U_answer',
#    'U_greeting',
#    'U_confirmation',
#    'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>',
#    '<UNK>',
#    'U_sequence_closer',
#    'U_sequence_closer',
#    'U_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'U_greeting', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'U_partial_request', 'A_sequence_closer', 'A_grant'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_sequence_closer'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_greeting'],
#   ['A_confirmation',
#    'A_completion_check',
#    'A_detail_request',
#    'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation', '<UNK>'],
#   ['U_confirmation', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_request_summary', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_confirmation', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_sequence_closer'],
#   ['<UNK>', 'A_sequence_closer'],
#   ['U_sequence_closer', 'U_sequence_closer'],
#   ['<UNK>', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_repair_initiator', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_partial_request'],
#   ['A_greeting', 'A_confirmation', 'A_grant', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'U_greeting'],
#   ['U_completion_check', 'U_partial_request', 'A_detail_request'],
#   ['A_grant', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_sequence_closer'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_confirmation', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_repair_initiator', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', 'U_confirmation', '<UNK>'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer', 'A_sequence_closer'],
#   ['<UNK>', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_greeting'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_detail_request', 'U_greeting', 'U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_confirmation', 'U_confirmation'],
#   ['U_partial_request', 'U_partial_request'],
#   ['A_grant', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['U_confirmation', '<UNK>'],
#   ['<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_sequence_closer'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_greeting', 'U_sequence_closer'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_sequence_closer'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>', 'A_greeting'],
#   ['A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer'],
#   ['A_confirmation', 'A_sequence_closer', 'U_sequence_closer', '<UNK>'],
#   ['A_greeting', '<UNK>'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_detail_request', 'A_greeting', 'A_sequence_closer'],
#   ['A_detail_request', 'U_confirmation', 'U_partial_request'],
#   ['U_answer', 'U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_receipt', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>'],
#   ['<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['U_confirmation', 'U_confirmation', 'A_detail_request', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'U_sequence_closer'],
#   ['A_greeting', 'U_confirmation'],
#   ['U_sequence_closer', 'U_sequence_closer', '<UNK>', '<ee>']],
#  [[],
#   ['<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_detail_request', 'A_detail_request'],
#   ['U_answer',
#    'A_hold_request',
#    'A_hold_request',
#    '<UNK>',
#    'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_hold_request', 'A_greeting'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_partial_request', 'U_answer'],
#   ['A_confirmation', 'A_grant', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<UNK>'],
#   ['U_sequence_closer', '<UNK>', 'A_sequence_closer'],
#   ['<UNK>', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer'],
#   ['A_confirmation', '<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_hold_request', 'A_hold_request', '<UNK>'],
#   ['A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_sequence_closer'],
#   ['U_answer', 'U_sequence_closer', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', 'U_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_request_summary', '<UNK>'],
#   ['U_sequence_closer', 'A_sequence_closer', '<UNK>'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'A_greeting', 'A_greeting'],
#   ['A_detail_request', 'A_confirmation'],
#   ['A_sequence_closer',
#    'A_request_summary',
#    'A_confirmation',
#    'A_detail_request'],
#   ['U_request_summary', 'U_confirmation'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_greeting'],
#   ['A_request_summary', 'A_confirmation', 'A_detail_request'],
#   ['U_request_summary', 'U_confirmation'],
#   ['U_answer', 'A_detail_request'],
#   ['U_greeting', 'U_partial_request'],
#   ['U_answer', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation', '<UNK>'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'U_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer'],
#   ['<UNK>', 'U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer',
#    '<UNK>',
#    'U_sequence_closer',
#    'U_confirmation',
#    'U_partial_request'],
#   ['A_confirmation', 'A_grant'],
#   ['U_confirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['A_detail_request', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'A_repair_initiator', 'A_confirmation'],
#   ['A_sequence_closer', 'A_repair_initiator', 'A_greeting'],
#   ['A_detail_request', 'U_answer', '<UNK>'],
#   ['U_confirmation', 'A_completion_check', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer'],
#   ['A_confirmation',
#    'A_sequence_closer',
#    'U_sequence_closer',
#    'A_hold_request',
#    '<UNK>',
#    'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_sequence_closer'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request', '<UNK>'],
#   ['<UNK>', 'U_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_request_summary', 'U_confirmation'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_partial_request'],
#   ['A_grant', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_completion_check', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_hold_request', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_partial_request'],
#   ['A_disconfirmation', 'A_grant'],
#   ['<UNK>', 'U_disconfirmation', 'U_partial_request'],
#   ['A_grant', 'U_greeting'],
#   ['U_partial_request', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_sequence_closer'],
#   ['A_detail_request', 'U_confirmation', 'U_partial_request', 'U_answer'],
#   ['A_confirmation', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_partial_request'],
#   ['A_greeting', 'A_grant', 'U_partial_request'],
#   ['A_confirmation', 'A_grant'],
#   ['U_confirmation', 'U_greeting', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', 'U_partial_request', '<UNK>'],
#   ['U_confirmation', '<UNK>', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_greeting', 'A_grant', 'U_partial_request', 'U_greeting'],
#   ['U_partial_request', 'A_grant', '<UNK>', 'U_partial_request'],
#   ['A_confirmation', 'A_grant'],
#   ['U_confirmation', '<UNK>'],
#   ['U_greeting', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'U_greeting'],
#   ['U_partial_request', 'A_greeting', 'A_grant', 'U_partial_request'],
#   ['A_grant', 'U_confirmation', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', 'U_partial_request'],
#   ['A_grant', 'U_partial_request'],
#   ['A_grant', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', '<UNK>'],
#   ['U_confirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_partial_request'],
#   ['A_grant', 'U_confirmation', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', 'A_sequence_closer'],
#   ['<UNK>', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['A_greeting', '<UNK>'],
#   ['A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation',
#    'U_answer',
#    '<UNK>',
#    'A_greeting',
#    'A_request_summary',
#    'U_confirmation'],
#   ['U_sequence_closer', 'A_sequence_closer', 'U_sequence_closer'],
#   ['A_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation', '<UNK>'],
#   ['A_hold_request', 'A_greeting'],
#   ['A_detail_request', 'A_hold_request', 'A_greeting'],
#   ['A_detail_request', 'U_partial_request'],
#   ['U_answer', 'A_grant'],
#   ['A_hold_request', '<UNK>'],
#   ['<UNK>', 'A_detail_request', 'A_hold_request', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer'],
#   ['U_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>'],
#   ['U_sequence_closer', 'U_partial_request', 'A_greeting'],
#   ['A_detail_request', 'A_grant', '<UNK>'],
#   ['A_confirmation', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer',
#    'U_sequence_closer',
#    'U_confirmation',
#    'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer',
#    'U_sequence_closer',
#    'U_sequence_closer',
#    'U_partial_request'],
#   ['A_greeting', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer',
#    '<UNK>',
#    'U_sequence_closer',
#    'A_confirmation',
#    'U_sequence_closer'],
#   ['U_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', 'U_partial_request'],
#   ['A_confirmation', 'A_grant'],
#   ['U_confirmation', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_disconfirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['U_confirmation', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['A_greeting', 'A_confirmation', 'U_greeting'],
#   ['A_confirmation', 'U_confirmation'],
#   ['A_confirmation', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['U_confirmation', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting', '<UNK>'],
#   ['U_sequence_closer', 'U_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting'],
#   ['A_detail_request',
#    'U_greeting',
#    'U_partial_request',
#    'U_answer',
#    'A_greeting'],
#   ['A_confirmation', 'A_detail_request'],
#   ['A_grant', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'U_sequence_closer', '<UNK>'],
#   ['U_confirmation', '<UNK>', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', 'U_sequence_closer'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'U_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_confirmation'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_hold_request', 'A_hold_request', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'U_greeting', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_request_summary', 'U_confirmation'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_partial_request', 'U_partial_request'],
#   ['A_grant', 'U_partial_request', 'U_partial_request'],
#   ['A_grant', 'U_confirmation', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['U_confirmation', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer',
#    'A_greeting',
#    'U_confirmation',
#    '<UNK>',
#    'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_sequence_closer'],
#   ['U_answer', 'U_confirmation', '<UNK>'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_sequence_closer', 'U_answer'],
#   ['A_confirmation', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['A_hold_request', '<UNK>', 'U_partial_request'],
#   ['A_grant', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_detail_request', 'U_confirmation'],
#   ['U_answer', 'U_sequence_closer'],
#   ['A_sequence_closer', 'A_sequence_closer'],
#   ['A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_greeting', 'A_confirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>', 'A_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_sequence_closer'],
#   ['<UNK>', 'U_sequence_closer', 'A_sequence_closer', 'U_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>'],
#   ['U_partial_request', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_greeting'],
#   ['A_detail_request', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_partial_request'],
#   ['U_answer', 'U_partial_request'],
#   ['U_repair_initiator', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', 'U_partial_request'],
#   ['A_grant', 'U_confirmation', 'U_confirmation'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request', 'A_sequence_closer'],
#   ['A_grant', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'A_greeting', 'A_greeting'],
#   ['A_detail_request', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_repair_initiator', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', 'U_greeting', 'U_partial_request'],
#   ['A_greeting', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation',
#    'U_answer',
#    'A_confirmation',
#    'A_repair_initiator',
#    'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'A_greeting'],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'A_greeting', 'A_greeting'],
#   ['A_detail_request', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer'],
#   ['A_confirmation', 'A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_greeting'],
#   ['U_partial_request',
#    'A_grant',
#    '<UNK>',
#    'A_sequence_closer',
#    'A_confirmation',
#    'U_sequence_closer',
#    '<ee>']],
#  [[],
#   ['A_greeting', 'U_greeting', 'A_greeting'],
#   ['A_detail_request', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_disconfirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_confirmation', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_greeting', 'U_sequence_closer'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer',
#    'U_partial_request',
#    'A_confirmation',
#    'A_detail_request'],
#   ['A_grant', 'U_answer', 'U_greeting'],
#   ['U_partial_request', 'A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'U_sequence_closer', '<UNK>', 'U_confirmation'],
# ...
#   ['A_grant', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_greeting'],
#   ['U_partial_request', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', 'U_partial_request'],
#   ['A_grant', 'U_partial_request', 'U_partial_request'],
#   ['A_grant', 'U_greeting'],
#   ['U_partial_request', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'U_greeting', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_detail_request', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_hold_request', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_confirmation', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>'],
#   ['A_confirmation', 'A_greeting'],
#   ['A_detail_request', 'U_partial_request'],
#   ['U_answer', 'A_grant', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_request_summary', 'A_confirmation', 'A_detail_request'],
#   ['U_confirmation',
#    'U_answer',
#    'A_hold_request',
#    'A_hold_request',
#    'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_answer', 'U_greeting'],
#   ['U_partial_request', 'A_detail_request', 'A_grant'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'U_sequence_closer'],
#   ['A_sequence_closer', 'A_greeting', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer', 'U_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'U_partial_request', 'A_greeting'],
#   ['A_detail_request', 'A_grant', 'A_greeting'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation', 'A_detail_request'],
#   ['U_greeting', 'U_partial_request', 'U_answer'],
#   ['A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_grant', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_partial_request'],
#   ['A_detail_request', 'A_grant'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'A_greeting'],
#   ['A_detail_request', 'U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'A_disconfirmation', 'U_partial_request', 'U_greeting'],
#   ['U_partial_request', 'U_partial_request', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>'],
#   ['U_confirmation', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer',
#    '<UNK>',
#    'U_sequence_closer',
#    'U_greeting',
#    'U_sequence_closer'],
#   ['U_sequence_closer', 'A_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_confirmation', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_detail_request', '<UNK>'],
#   ['<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['A_greeting', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'U_sequence_closer'],
#   ['A_confirmation', '<UNK>'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_request_summary', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_sequence_closer', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_sequence_closer'],
#   ['<UNK>', 'U_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_sequence_closer'],
#   ['A_sequence_closer', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_disconfirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting',
#    'A_detail_request',
#    'A_confirmation',
#    'A_confirmation',
#    'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>',
#    'U_confirmation',
#    'A_hold_request',
#    'A_detail_request',
#    'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting', '<UNK>'],
#   ['A_greeting', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_greeting'],
#   ['A_confirmation', 'A_completion_check', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_sequence_closer'],
#   ['<UNK>', 'A_sequence_closer', 'A_sequence_closer'],
#   ['A_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_hold_request', 'A_hold_request', 'U_partial_request'],
#   ['A_greeting',
#    'A_grant',
#    'U_partial_request',
#    'A_detail_request',
#    'A_grant'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['<UNK>', '<UNK>'],
#   ['<UNK>', '<UNK>', 'U_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_detail_request', 'U_greeting', 'U_answer'],
#   ['A_confirmation', '<UNK>', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['A_confirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', '<UNK>', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_greeting', 'U_answer'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'U_partial_request'],
#   ['A_grant', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['A_confirmation', '<UNK>'],
#   ['U_partial_request', '<UNK>', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_sequence_closer', 'A_sequence_closer'],
#   ['U_sequence_closer', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['<UNK>', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'A_disconfirmation', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting'],
#   ['A_detail_request', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_greeting', '<UNK>'],
#   ['<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>'],
#   ['A_confirmation', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_detail_request'],
#   ['U_greeting', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_hold_request', '<UNK>'],
#   ['<UNK>', 'U_partial_request'],
#   ['A_greeting', 'A_grant', 'U_partial_request'],
#   ['A_confirmation', 'A_grant', 'A_greeting'],
#   ['A_completion_check', 'A_detail_request'],
#   ['U_answer', '<UNK>', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_greeting'],
#   ['A_detail_request', 'A_confirmation'],
#   ['A_sequence_closer', 'A_sequence_closer', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['A_greeting', 'A_detail_request'],
#   ['U_greeting', 'U_answer', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'U_confirmation', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_sequence_closer'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer'],
#   ['A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_answer', 'U_greeting', 'U_sequence_closer', 'A_detail_request'],
#   ['U_disconfirmation', 'U_answer'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer'],
#   ['A_confirmation', '<UNK>'],
#   ['U_confirmation', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_confirmation', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation', 'U_partial_request'],
#   ['A_grant', 'U_confirmation', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_receipt', '<UNK>'],
#   ['U_confirmation', 'U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_greeting', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['A_confirmation', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', 'A_greeting'],
#   ['A_detail_request', 'U_answer', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_detail_request', 'U_confirmation'],
#   ['U_sequence_closer', 'U_answer'],
#   ['<UNK>', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'A_greeting'],
#   ['A_detail_request', 'U_answer', '<UNK>'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>'],
#   ['U_repair_initiator', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_sequence_closer'],
#   ['A_confirmation', '<UNK>'],
#   ['U_sequence_closer', '<UNK>', 'U_sequence_closer', 'U_sequence_closer'],
#   ['A_receipt', 'A_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>', 'A_greeting'],
#   ['A_detail_request', 'A_greeting', '<UNK>'],
#   ['A_sequence_closer', '<UNK>'],
#   ['U_confirmation', 'U_partial_request'],
#   ['A_hold_request', 'A_grant'],
#   ['A_repair_initiator', 'A_disconfirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'A_sequence_closer', '<UNK>'],
#   ['U_sequence_closer', 'A_hold_request', '<UNK>'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_confirmation'],
#   ['U_sequence_closer', 'A_confirmation'],
#   ['A_sequence_closer', 'U_partial_request'],
#   ['A_grant', 'U_sequence_closer'],
#   ['<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>'],
#   ['A_confirmation', '<UNK>'],
#   ['A_confirmation', '<UNK>', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', 'U_confirmation'],
#   ['U_sequence_closer', 'U_partial_request'],
#   ['A_disconfirmation', 'A_grant'],
#   ['U_confirmation', 'U_sequence_closer', '<UNK>', 'A_confirmation'],
#   ['A_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<UNK>', 'U_confirmation'],
#   ['U_sequence_closer', '<ee>']],
#  [[],
#   ['U_greeting', '<UNK>'],
#   ['A_greeting', 'A_greeting'],
#   ['A_detail_request', 'A_confirmation', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_answer', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', '<UNK>', 'A_greeting', 'A_confirmation'],
#   ['A_sequence_closer', 'A_completion_check', 'A_detail_request'],
#   ['U_answer', 'A_confirmation', '<UNK>'],
#   ['<UNK>', '<UNK>', 'A_greeting', 'A_detail_request'],
#   ['U_confirmation', 'U_answer', 'U_partial_request'],
#   ['A_grant', '<UNK>'],
#   ['<UNK>', '<UNK>', '<UNK>', 'A_confirmation', '<UNK>'],
#   ['A_greeting', 'A_detail_request'],
#   ['U_answer', 'U_confirmation', 'A_confirmation'],
#   ['<UNK>', 'U_confirmation'],
#   ['U_sequence_closer',
#    'U_sequence_closer',
#    '<UNK>',
#    'A_sequence_closer',
#    '<ee>']],
#  [[],
#   ['U_confirmation', 'A_confirmation'],
#   ['A_sequence_closer', 'A_detail_request'],
#   ['U_greeting', 'U_answer'],
#   ['A_confirmation', 'U_confirmation', 'U_partial_request'],
#   ['A_grant', 'A_confirmation', 'A_detail_request'],
#   ['U_answer', 'U_partial_request'],
#   ['A_greeting', 'A_confirmation', 'A_grant', 'U_sequence_closer', '<UNK>'],
#   ['<UNK>', 'U_sequence_closer', '<UNK>'],
#   ['A_confirmation', 'U_sequence_closer'],
#   ['A_sequence_closer', 'A_sequence_closer', '<ee>']],
#  ...]

# %%
#count times each da sequence appear. put in dict. k==seq, value ==count
seq_counts = {}

for seq in all_da_seq:
    for sub_seq in seq:
        sub_seq = ' '.join(sub_seq)
        seq_counts[sub_seq] = seq_counts[sub_seq] + 1 if sub_seq in seq_counts else 1
        
        
import operator

sorted_d = dict(sorted(seq_counts.items(), key=operator.itemgetter(1),reverse=True))
sorted_d
# Out:
# {'': 17288,
#  'A_sequence_closer A_detail_request': 8476,
#  'U_answer A_confirmation': 7806,
#  'U_answer A_detail_request': 5684,
#  'U_sequence_closer U_partial_request': 4760,
#  'U_sequence_closer <ee>': 4642,
#  'A_grant U_confirmation': 4561,
#  'A_greeting A_detail_request': 4526,
#  'A_completion_check A_detail_request': 3644,
#  'A_greeting A_greeting A_detail_request': 3363,
#  'A_sequence_closer <UNK>': 3048,
#  'A_grant U_partial_request': 2920,
#  '<UNK> U_confirmation': 2450,
#  'U_sequence_closer <UNK>': 2380,
#  'U_answer <UNK>': 2303,
#  '<UNK> A_confirmation': 2215,
#  'A_sequence_closer <ee>': 2200,
#  'U_confirmation U_answer A_confirmation': 1902,
#  'U_greeting U_partial_request': 1707,
#  'A_grant <UNK>': 1681,
#  '<UNK> A_detail_request': 1621,
#  'A_greeting A_grant U_confirmation': 1573,
#  'A_confirmation A_detail_request': 1504,
#  'A_greeting A_grant U_partial_request': 1488,
#  '<UNK> <UNK>': 1338,
#  'U_greeting U_answer A_confirmation': 1335,
#  '<UNK> U_partial_request': 1311,
#  'U_partial_request A_confirmation': 1290,
#  '<UNK> <ee>': 1224,
#  'U_greeting U_answer <UNK>': 1188,
#  'U_confirmation U_answer A_detail_request': 1185,
#  'U_confirmation U_answer <UNK>': 1172,
#  'U_greeting <UNK>': 1135,
#  'A_sequence_closer A_greeting': 1112,
#  'U_sequence_closer U_greeting': 1095,
#  'U_answer A_greeting': 1087,
#  'A_sequence_closer U_confirmation': 1063,
#  'U_sequence_closer U_answer': 1055,
#  'A_receipt A_sequence_closer <ee>': 1006,
#  'A_grant U_sequence_closer': 936,
#  'U_greeting U_confirmation': 915,
#  'U_sequence_closer A_confirmation': 898,
#  'U_greeting A_greeting': 896,
#  'A_greeting A_greeting': 895,
#  'A_sequence_closer A_completion_check A_detail_request': 894,
#  'U_greeting U_answer A_detail_request': 888,
#  '<UNK> A_greeting': 880,
#  'U_sequence_closer <UNK> U_confirmation': 873,
#  'U_sequence_closer U_sequence_closer': 866,
#  'A_grant U_greeting': 857,
#  'U_partial_request A_grant U_confirmation': 838,
#  'A_grant U_answer': 831,
#  'U_sequence_closer A_sequence_closer <ee>': 815,
#  'A_confirmation <UNK>': 795,
#  'U_sequence_closer A_detail_request': 791,
#  'U_answer A_grant': 773,
#  'U_sequence_closer U_sequence_closer <ee>': 772,
#  'A_greeting A_grant U_greeting U_partial_request': 752,
#  'A_greeting <UNK>': 745,
#  'U_answer <UNK> A_detail_request': 713,
#  'U_answer <UNK> A_confirmation': 706,
#  'U_sequence_closer A_greeting': 664,
#  'U_confirmation <UNK>': 663,
#  'A_confirmation A_grant U_confirmation': 655,
#  'U_sequence_closer U_greeting U_partial_request': 641,
#  'U_answer A_greeting A_confirmation': 637,
#  'U_partial_request A_grant U_partial_request': 637,
#  'A_detail_request A_confirmation': 634,
#  '<UNK> <UNK> U_confirmation': 632,
#  'A_sequence_closer U_sequence_closer <ee>': 627,
#  'A_sequence_closer A_sequence_closer': 622,
#  'U_answer A_greeting A_detail_request': 617,
#  '<UNK> U_greeting': 611,
#  'A_receipt A_sequence_closer': 605,
#  'A_sequence_closer <UNK> U_confirmation': 597,
#  'U_greeting U_answer': 590,
#  'U_confirmation U_partial_request': 586,
#  '<UNK> U_sequence_closer': 577,
#  'U_answer A_confirmation A_detail_request': 571,
#  'U_greeting U_answer U_partial_request': 569,
#  'A_sequence_closer U_sequence_closer': 567,
#  'A_detail_request A_grant': 563,
#  'A_sequence_closer <UNK> A_confirmation': 556,
#  'A_confirmation A_completion_check A_detail_request': 552,
#  'A_detail_request U_partial_request': 547,
#  'A_detail_request A_detail_request': 546,
#  '<UNK> A_sequence_closer': 534,
#  'A_confirmation A_grant <UNK>': 528,
#  'A_greeting A_grant U_greeting': 526,
#  '<UNK> A_sequence_closer <ee>': 518,
#  'A_greeting A_confirmation': 506,
#  '<UNK> <UNK> A_confirmation': 499,
#  'U_partial_request A_grant U_greeting': 480,
#  'U_partial_request U_answer': 472,
#  'U_greeting U_answer <UNK> A_confirmation': 469,
#  'A_greeting U_greeting': 463,
#  'A_sequence_closer <UNK> A_detail_request': 459,
#  'U_answer <UNK> U_confirmation': 458,
#  'U_confirmation U_answer': 456,
#  'A_grant <UNK> U_confirmation': 448,
#  'U_answer U_partial_request': 447,
#  'A_sequence_closer A_grant': 445,
#  'A_confirmation A_grant U_partial_request': 443,
#  'A_sequence_closer U_partial_request': 436,
#  'A_hold_request <UNK>': 432,
#  '<UNK> U_sequence_closer <ee>': 428,
#  'A_sequence_closer A_confirmation': 427,
#  'A_greeting U_confirmation': 420,
#  'A_greeting A_detail_request U_partial_request': 419,
#  'U_sequence_closer A_sequence_closer': 417,
#  'A_receipt <ee>': 416,
#  'A_grant U_greeting U_partial_request': 414,
#  'A_grant <UNK> U_partial_request': 412,
#  'U_answer U_sequence_closer': 408,
#  'U_partial_request U_partial_request': 403,
#  'U_greeting U_answer <UNK> A_detail_request': 399,
#  'U_sequence_closer <UNK> A_confirmation': 398,
#  'A_greeting A_grant <UNK>': 395,
#  'U_partial_request A_grant <UNK>': 394,
#  'U_partial_request A_detail_request': 388,
#  'A_hold_request A_grant': 382,
#  'U_answer A_grant U_confirmation': 373,
#  '<UNK> <UNK> A_detail_request': 370,
#  'A_sequence_closer A_sequence_closer <ee>': 370,
#  'U_sequence_closer <UNK> U_partial_request': 365,
#  'U_confirmation U_answer U_partial_request': 358,
#  'U_sequence_closer U_confirmation': 357,
#  'U_partial_request U_greeting': 353,
#  'U_partial_request A_greeting': 346,
#  'U_partial_request <UNK>': 344,
#  'A_detail_request U_answer A_confirmation': 343,
#  'A_detail_request U_confirmation': 339,
#  'A_sequence_closer A_detail_request U_partial_request': 338,
#  'U_confirmation U_answer <UNK> A_confirmation': 337,
#  'A_grant U_greeting U_confirmation': 335,
#  'U_greeting A_confirmation': 333,
#  'A_sequence_closer A_detail_request U_confirmation': 332,
#  'U_answer A_sequence_closer': 331,
#  'U_answer A_grant U_partial_request': 328,
#  'U_request_summary U_confirmation': 328,
#  '<UNK> <UNK> <UNK>': 327,
#  'U_sequence_closer U_sequence_closer A_sequence_closer <ee>': 323,
#  '<UNK> <UNK> U_partial_request': 323,
#  '<UNK> A_greeting A_detail_request': 319,
#  'A_grant A_greeting': 317,
#  'A_detail_request <UNK>': 314,
#  'A_confirmation U_confirmation': 305,
#  'U_answer A_confirmation <UNK>': 302,
#  'U_confirmation A_confirmation': 298,
#  'A_sequence_closer A_hold_request <UNK>': 292,
#  'A_greeting A_grant U_greeting U_confirmation': 289,
#  'U_partial_request U_answer A_greeting': 287,
#  'U_confirmation U_answer <UNK> A_detail_request': 286,
#  'A_sequence_closer A_detail_request A_detail_request': 286,
#  'A_sequence_closer U_greeting': 285,
#  'U_partial_request A_grant U_greeting U_partial_request': 282,
#  'A_confirmation A_greeting': 277,
#  'A_greeting U_partial_request': 268,
#  'A_repair_initiator A_detail_request': 267,
#  'U_confirmation U_answer U_sequence_closer': 265,
#  'A_grant A_detail_request': 265,
#  'U_confirmation U_answer <UNK> U_confirmation': 264,
#  'U_sequence_closer U_sequence_closer U_sequence_closer': 256,
#  'U_greeting U_sequence_closer': 255,
#  'U_greeting U_greeting': 250,
#  'U_greeting U_answer A_greeting': 249,
#  'A_detail_request A_greeting': 242,
#  'U_sequence_closer U_answer <UNK>': 241,
#  'U_confirmation U_answer A_greeting': 241,
#  'U_partial_request A_greeting A_grant U_confirmation': 239,
#  'U_sequence_closer <UNK> A_detail_request': 237,
#  'A_confirmation A_grant A_detail_request': 237,
#  'U_greeting U_answer U_greeting': 234,
#  'A_confirmation A_grant U_sequence_closer': 231,
#  'A_grant U_answer A_detail_request': 230,
#  'U_greeting <UNK> A_greeting': 227,
#  'A_greeting U_greeting <UNK>': 226,
#  'U_answer A_grant <UNK>': 225,
#  '<UNK> A_greeting <UNK>': 225,
#  'A_receipt <UNK>': 224,
#  'A_greeting A_grant U_sequence_closer': 222,
#  'U_greeting U_partial_request A_greeting': 221,
#  'U_answer <UNK> U_partial_request': 219,
#  'U_sequence_closer <UNK> U_sequence_closer': 218,
#  'A_greeting A_grant A_greeting': 217,
#  'A_sequence_closer A_grant <UNK>': 213,
#  'U_confirmation U_answer A_sequence_closer': 211,
#  'A_confirmation A_grant': 211,
#  '<UNK> <UNK> A_greeting': 205,
#  'A_grant U_confirmation U_partial_request': 204,
#  'A_grant U_sequence_closer U_partial_request': 201,
#  'U_sequence_closer <UNK> A_sequence_closer <ee>': 201,
#  '<UNK> <UNK> A_greeting A_detail_request': 200,
#  'U_answer U_greeting': 199,
#  'A_detail_request U_answer A_detail_request': 189,
#  '<UNK> <UNK> <UNK> U_confirmation': 187,
#  '<UNK> A_greeting A_confirmation': 187,
#  'U_disconfirmation U_answer': 185,
#  'U_confirmation A_detail_request': 180,
#  'U_sequence_closer <UNK> <ee>': 180,
#  'U_sequence_closer U_partial_request U_partial_request': 179,
#  'A_detail_request A_confirmation A_detail_request': 176,
#  'A_greeting A_grant <UNK> U_partial_request': 176,
#  'A_grant U_confirmation U_sequence_closer': 172,
#  'U_answer U_confirmation': 171,
#  'A_greeting U_greeting A_confirmation': 171,
#  'U_sequence_closer <UNK> U_greeting': 170,
#  'A_request_summary A_confirmation A_detail_request': 170,
#  'U_confirmation U_answer U_greeting': 170,
#  'U_greeting U_answer A_greeting A_detail_request': 169,
#  '<UNK> A_confirmation A_detail_request': 169,
#  'A_sequence_closer <UNK> U_partial_request': 168,
#  'U_greeting U_answer <UNK> U_partial_request': 167,
#  'U_partial_request A_hold_request A_grant': 166,
#  'U_partial_request A_greeting A_confirmation A_grant U_partial_request': 166,
#  'A_sequence_closer <UNK> U_sequence_closer': 165,
#  'U_greeting U_answer A_greeting A_confirmation': 165,
#  'U_sequence_closer <UNK> A_sequence_closer': 162,
#  '<UNK> U_sequence_closer <UNK>': 161,
#  'U_sequence_closer U_sequence_closer <UNK>': 161,
#  'A_sequence_closer <UNK> A_greeting': 160,
#  'U_confirmation U_answer A_greeting A_confirmation': 159,
#  'A_sequence_closer A_greeting A_detail_request': 158,
#  'U_confirmation A_greeting': 158,
#  'U_greeting A_detail_request': 158,
#  'A_detail_request U_partial_request U_answer': 157,
#  'U_sequence_closer U_answer U_sequence_closer': 156,
#  'U_confirmation U_greeting': 156,
#  'U_partial_request A_greeting A_confirmation A_grant U_confirmation': 156,
#  'U_sequence_closer U_answer A_detail_request': 155,
#  'U_confirmation U_sequence_closer': 155,
#  'A_confirmation U_sequence_closer': 154,
#  'U_confirmation U_answer A_greeting A_detail_request': 154,
#  'U_answer <UNK> A_greeting': 153,
#  'U_answer A_confirmation A_greeting': 152,
#  'U_sequence_closer A_sequence_closer A_sequence_closer <ee>': 152,
#  'A_grant U_confirmation <UNK>': 151,
#  'A_sequence_closer A_detail_request A_confirmation': 151,
#  'U_sequence_closer A_greeting U_confirmation': 149,
#  'U_greeting <UNK> A_confirmation': 149,
#  'A_detail_request U_sequence_closer': 149,
#  'A_detail_request U_greeting U_partial_request': 146,
#  'A_receipt A_sequence_closer A_sequence_closer <ee>': 146,
#  '<UNK> A_confirmation <UNK>': 145,
#  'U_sequence_closer U_answer A_sequence_closer': 144,
#  'U_sequence_closer U_sequence_closer A_sequence_closer': 144,
#  'U_greeting A_greeting A_detail_request': 144,
#  'A_disconfirmation A_grant': 142,
#  '<UNK> U_sequence_closer U_sequence_closer': 142,
#  'A_sequence_closer <UNK> <ee>': 142,
#  'A_grant <UNK> A_confirmation': 141,
#  '<UNK> U_confirmation <UNK>': 140,
#  'U_partial_request A_greeting A_grant U_greeting U_partial_request': 139,
#  'A_sequence_closer A_grant A_detail_request': 138,
#  'A_receipt U_sequence_closer': 137,
#  'U_sequence_closer U_answer U_partial_request': 137,
#  'A_greeting U_greeting <UNK> A_confirmation': 136,
#  '<UNK> A_greeting A_greeting': 136,
#  '<UNK> <UNK> A_greeting <UNK>': 136,
#  'A_sequence_closer U_confirmation <UNK>': 135,
#  'U_greeting A_greeting A_greeting': 135,
#  'U_sequence_closer U_partial_request A_detail_request': 135,
#  'A_sequence_closer A_sequence_closer A_sequence_closer': 135,
#  'A_confirmation A_grant <UNK> U_confirmation': 133,
#  'U_sequence_closer U_sequence_closer A_confirmation': 132,
#  'U_partial_request A_greeting A_confirmation A_grant': 132,
#  'U_answer A_hold_request <UNK>': 131,
#  'U_sequence_closer U_partial_request A_confirmation': 131,
#  'U_answer A_sequence_closer <ee>': 131,
#  'A_greeting A_detail_request U_greeting U_partial_request': 130,
#  'U_partial_request A_grant U_sequence_closer': 130,
#  'U_sequence_closer U_sequence_closer U_partial_request': 128,
#  '<UNK> <UNK> U_greeting': 128,
#  'U_answer A_sequence_closer A_detail_request': 127,
#  'U_sequence_closer U_sequence_closer A_greeting': 127,
#  'U_sequence_closer <UNK> A_greeting': 127,
#  'A_sequence_closer A_detail_request U_sequence_closer': 126,
#  'A_sequence_closer A_hold_request U_confirmation': 126,
#  'A_grant U_answer <UNK>': 125,
#  'U_sequence_closer A_greeting <UNK>': 125,
#  '<UNK> <UNK> <UNK> A_confirmation': 125,
#  'A_confirmation <UNK> A_confirmation': 125,
#  'U_sequence_closer U_confirmation <UNK>': 124,
#  'U_greeting <UNK> A_detail_request': 124,
#  'U_sequence_closer U_partial_request <UNK>': 124,
#  'U_partial_request A_greeting A_grant U_greeting': 124,
#  'U_confirmation U_sequence_closer U_partial_request': 123,
#  'A_grant <UNK> U_greeting': 123,
#  'U_answer U_greeting A_confirmation': 122,
#  'A_sequence_closer U_sequence_closer <UNK>': 122,
#  'U_partial_request A_greeting A_grant U_partial_request': 122,
#  'A_sequence_closer A_greeting <UNK>': 120,
#  'A_detail_request A_grant <UNK>': 119,
#  'A_request_summary A_confirmation': 119,
#  '<UNK> U_greeting <UNK>': 119,
#  'A_hold_request A_grant <UNK>': 117,
#  'U_greeting U_answer <UNK> U_greeting': 117,
#  'U_confirmation U_sequence_closer <UNK>': 115,
#  'A_detail_request U_greeting U_confirmation': 114,
#  '<UNK> <UNK> <UNK> A_detail_request': 113,
#  'A_greeting A_grant <UNK> U_confirmation': 113,
#  'U_sequence_closer A_greeting A_detail_request': 111,
#  'A_greeting <UNK> A_confirmation': 110,
#  '<UNK> <UNK> <UNK> U_partial_request': 108,
#  'U_sequence_closer U_greeting <UNK>': 107,
#  'A_grant U_sequence_closer <ee>': 106,
#  'U_answer U_sequence_closer A_confirmation': 106,
#  'U_partial_request U_confirmation': 106,
#  'A_detail_request U_answer <UNK>': 105,
#  'A_sequence_closer A_confirmation A_detail_request': 105,
#  'U_greeting U_answer U_sequence_closer': 105,
#  'U_sequence_closer U_greeting U_sequence_closer': 105,
#  'U_partial_request A_grant U_greeting U_confirmation': 105,
#  'U_answer U_greeting <UNK>': 105,
#  'A_hold_request U_confirmation': 104,
#  '<UNK> A_greeting U_confirmation': 104,
#  'A_grant A_greeting U_confirmation': 103,
#  'U_sequence_closer A_sequence_closer U_sequence_closer': 102,
#  'A_sequence_closer U_confirmation A_detail_request': 102,
#  'A_sequence_closer A_sequence_closer U_sequence_closer': 102,
#  '<UNK> U_greeting U_confirmation': 102,
#  'A_sequence_closer A_detail_request <UNK>': 101,
#  'U_answer A_repair_initiator A_detail_request': 100,
#  'A_confirmation A_sequence_closer A_detail_request': 100,
#  'A_confirmation U_greeting': 100,
#  'U_partial_request U_answer A_confirmation': 99,
#  'A_grant A_confirmation': 99,
#  '<UNK> U_sequence_closer U_partial_request': 99,
#  'A_grant U_sequence_closer <UNK>': 99,
#  'A_receipt U_sequence_closer <ee>': 98,
#  'A_confirmation A_sequence_closer <UNK>': 96,
#  'A_greeting U_greeting A_detail_request': 96,
#  'A_confirmation A_grant A_greeting': 96,
#  'U_answer <UNK> A_greeting A_detail_request': 96,
#  'U_sequence_closer A_greeting A_confirmation': 95,
#  'A_confirmation A_grant U_greeting': 95,
#  'U_sequence_closer U_answer A_sequence_closer <ee>': 94,
#  'U_answer A_greeting U_confirmation': 94,
#  'A_receipt A_sequence_closer A_sequence_closer': 94,
#  'U_sequence_closer A_sequence_closer A_sequence_closer': 94,
#  'A_confirmation U_partial_request': 94,
#  'U_confirmation U_answer U_confirmation': 92,
#  'U_confirmation U_answer <UNK> U_sequence_closer': 92,
#  'U_sequence_closer U_sequence_closer U_sequence_closer <ee>': 92,
#  'A_sequence_closer A_detail_request U_partial_request U_answer': 92,
#  '<UNK> U_confirmation U_partial_request': 91,
#  'A_detail_request U_greeting U_partial_request U_answer': 91,
#  'A_greeting A_confirmation A_detail_request': 91,
#  '<UNK> U_greeting U_partial_request': 90,
#  'U_partial_request A_detail_request A_grant': 90,
#  'U_greeting <UNK> U_partial_request': 90,
#  'A_greeting <UNK> A_detail_request': 89,
#  'A_greeting U_sequence_closer': 89,
#  'A_repair_initiator A_grant': 89,
#  'U_confirmation U_confirmation': 88,
#  'U_sequence_closer <UNK> U_sequence_closer <ee>': 88,
#  'A_sequence_closer <UNK> A_sequence_closer': 88,
#  '<UNK> U_sequence_closer A_sequence_closer': 88,
#  'U_confirmation U_answer <UNK> A_greeting': 88,
#  'A_sequence_closer A_greeting U_confirmation': 88,
#  'A_completion_check A_detail_request A_greeting': 87,
#  'U_sequence_closer U_confirmation U_partial_request': 86,
#  'A_greeting A_grant U_sequence_closer U_partial_request': 86,
#  'U_answer A_completion_check A_detail_request': 85,
#  'A_greeting A_confirmation A_grant U_partial_request': 85,
#  'A_confirmation <UNK> A_detail_request': 84,
#  'A_grant A_hold_request <UNK>': 84,
#  'U_answer <UNK> U_sequence_closer': 84,
#  'U_completion_check U_partial_request': 84,
#  'A_grant A_greeting U_partial_request': 83,
#  'U_partial_request A_grant <UNK> U_confirmation': 83,
#  'A_disconfirmation A_sequence_closer': 82,
#  '<UNK> U_sequence_closer A_sequence_closer <ee>': 81,
#  'A_sequence_closer U_greeting A_confirmation': 81,
#  'A_sequence_closer A_detail_request U_greeting U_confirmation': 81,
#  'U_greeting U_partial_request U_answer': 81,
#  '<UNK> U_sequence_closer A_confirmation': 80,
#  'U_greeting U_answer A_sequence_closer': 80,
#  'A_greeting A_sequence_closer': 80,
#  'A_grant A_greeting <UNK>': 80,
#  'U_confirmation U_sequence_closer A_detail_request': 79,
#  'A_sequence_closer U_sequence_closer A_detail_request': 79,
#  'A_sequence_closer A_detail_request U_sequence_closer U_answer': 79,
#  '<UNK> U_sequence_closer A_greeting': 79,
#  'A_sequence_closer <UNK> U_sequence_closer <ee>': 79,
#  'U_greeting U_partial_request U_answer A_greeting': 79,
#  'U_greeting A_greeting A_confirmation': 79,
#  '<UNK> A_sequence_closer U_sequence_closer': 79,
#  'U_partial_request A_greeting A_grant <UNK>': 79,
#  'U_greeting U_answer <UNK> U_confirmation': 78,
#  '<UNK> <UNK> <UNK> A_greeting A_detail_request': 78,
#  'A_confirmation A_grant <UNK> U_partial_request': 78,
#  'U_greeting U_answer U_greeting <UNK>': 78,
#  'U_greeting U_answer U_greeting A_confirmation': 78,
#  'A_grant U_sequence_closer U_sequence_closer': 78,
#  'U_answer A_greeting <UNK>': 77,
#  'U_greeting U_confirmation U_partial_request': 77,
#  'A_sequence_closer A_detail_request U_greeting': 77,
#  'U_partial_request A_greeting A_confirmation A_grant U_greeting': 77,
#  'U_answer A_grant A_detail_request': 76,
#  'U_confirmation U_answer <UNK> U_partial_request': 75,
#  'A_greeting U_greeting <UNK> A_detail_request': 75,
#  'A_confirmation <UNK> U_confirmation': 74,
#  'U_partial_request A_grant <UNK> U_partial_request': 74,
#  'U_answer A_detail_request U_partial_request': 74,
#  'A_sequence_closer A_hold_request A_detail_request': 74,
#  'U_confirmation U_answer A_greeting U_confirmation': 73,
#  'A_completion_check A_detail_request U_confirmation': 73,
#  'U_confirmation U_sequence_closer U_greeting': 73,
#  'U_confirmation U_answer U_sequence_closer A_confirmation': 72,
#  'U_sequence_closer A_confirmation <UNK>': 72,
#  'A_grant U_partial_request U_partial_request': 72,
#  '<UNK> <UNK> U_sequence_closer': 72,
#  '<UNK> <UNK> U_confirmation <UNK>': 71,
#  'U_answer <UNK> A_greeting A_confirmation': 71,
#  'A_sequence_closer <UNK> A_greeting A_detail_request': 71,
#  'A_grant <UNK> A_detail_request': 71,
#  'U_partial_request A_grant <UNK> U_greeting': 71,
#  'A_detail_request A_confirmation <UNK>': 71,
#  'A_grant U_sequence_closer U_greeting': 71,
#  'A_detail_request A_greeting A_confirmation': 70,
#  'A_completion_check A_detail_request U_partial_request': 70,
#  'A_grant A_sequence_closer': 70,
#  'A_greeting A_detail_request U_greeting U_partial_request U_answer': 70,
#  'U_sequence_closer U_sequence_closer <UNK> A_sequence_closer <ee>': 69,
#  'U_sequence_closer U_sequence_closer A_sequence_closer A_sequence_closer <ee>': 69,
#  'U_sequence_closer U_sequence_closer A_detail_request': 69,
#  'A_hold_request A_detail_request': 69,
#  'A_greeting A_detail_request U_partial_request U_answer': 69,
#  'A_sequence_closer A_request_summary A_confirmation A_detail_request': 68,
#  'A_receipt A_sequence_closer <UNK>': 68,
#  'U_sequence_closer U_partial_request U_greeting': 68,
#  'U_answer A_detail_request U_confirmation': 67,
#  'A_greeting A_confirmation A_grant <UNK>': 67,
#  'U_answer U_greeting A_detail_request': 67,
#  'A_greeting A_grant <UNK> U_greeting': 67,
#  'U_sequence_closer <UNK> A_greeting A_detail_request': 66,
#  'U_confirmation <UNK> A_confirmation': 66,
#  'U_sequence_closer U_partial_request U_confirmation': 66,
#  'A_sequence_closer A_detail_request A_grant': 66,
#  'A_confirmation A_grant U_sequence_closer U_partial_request': 66,
#  'U_sequence_closer A_sequence_closer <UNK>': 65,
#  'A_hold_request A_greeting': 65,
#  '<UNK> A_sequence_closer <UNK>': 65,
#  'A_sequence_closer <UNK> A_sequence_closer <ee>': 65,
#  'A_receipt A_greeting': 65,
#  'U_answer A_confirmation U_confirmation': 64,
#  'U_answer A_confirmation <UNK> A_confirmation': 64,
#  'A_confirmation A_confirmation': 64,
#  'A_sequence_closer U_sequence_closer U_sequence_closer': 64,
#  'U_answer <UNK> U_greeting': 64,
#  'A_grant U_confirmation U_greeting': 64,
#  'U_answer U_confirmation A_confirmation': 63,
#  'U_answer A_detail_request A_detail_request': 63,
#  'A_sequence_closer A_sequence_closer U_confirmation': 63,
#  'U_sequence_closer U_answer A_confirmation': 63,
#  'U_repair_initiator U_partial_request': 63,
#  'U_sequence_closer U_partial_request A_greeting A_confirmation A_grant U_confirmation': 63,
#  'A_detail_request U_greeting U_partial_request U_answer A_greeting': 62,
#  '<UNK> <UNK> A_greeting A_confirmation': 61,
#  'U_confirmation U_sequence_closer A_greeting': 61,
#  'A_sequence_closer U_confirmation A_confirmation': 60,
#  'A_greeting U_greeting U_greeting': 60,
#  'A_receipt <UNK> <ee>': 60,
#  'U_sequence_closer U_sequence_closer <UNK> <ee>': 60,
#  'U_partial_request U_answer A_detail_request': 60,
#  'U_answer A_grant U_sequence_closer': 60,
#  'U_sequence_closer <UNK> A_greeting U_confirmation': 60,
#  'A_sequence_closer A_grant A_greeting': 60,
#  'U_sequence_closer U_greeting A_confirmation': 60,
#  '<UNK> A_sequence_closer U_confirmation': 59,
#  'U_greeting U_greeting <UNK>': 59,
#  'A_sequence_closer A_greeting A_confirmation': 59,
#  'A_grant U_partial_request A_detail_request': 59,
#  'U_greeting U_greeting A_greeting': 59,
#  'A_greeting A_detail_request U_greeting U_partial_request U_answer A_greeting': 59,
#  'A_request_summary A_detail_request': 58,
#  'U_sequence_closer A_hold_request <UNK>': 58,
#  'U_greeting A_greeting <UNK>': 58,
#  'A_receipt A_sequence_closer U_sequence_closer': 58,
#  'A_greeting <UNK> U_partial_request': 58,
#  'U_answer <UNK> A_sequence_closer': 57,
#  '<UNK> A_hold_request <UNK>': 57,
#  'A_sequence_closer <UNK> U_sequence_closer <UNK>': 57,
#  'U_confirmation A_sequence_closer': 57,
#  'A_detail_request A_grant A_detail_request': 57,
#  '<UNK> U_partial_request <UNK>': 56,
#  'U_answer U_confirmation <UNK>': 56,
#  'U_answer U_partial_request A_confirmation': 56,
#  'U_sequence_closer U_sequence_closer U_greeting': 56,
#  '<UNK> U_partial_request A_confirmation': 56,
#  'A_sequence_closer A_confirmation <UNK>': 56,
#  'U_partial_request A_greeting A_confirmation A_grant <UNK>': 56,
#  '<UNK> <UNK> A_sequence_closer': 55,
#  'A_sequence_closer <UNK> U_greeting': 55,
#  'U_partial_request A_grant A_detail_request': 54,
#  'U_greeting U_answer <UNK> A_greeting A_detail_request': 54,
#  '<UNK> <UNK> U_sequence_closer <UNK>': 54,
#  'A_greeting A_grant U_confirmation U_partial_request': 54,
#  'A_confirmation A_detail_request A_grant': 54,
#  '<UNK> A_sequence_closer A_sequence_closer': 53,
#  'A_detail_request <UNK> A_detail_request': 53,
#  '<UNK> U_confirmation U_sequence_closer': 53,
#  '<UNK> U_partial_request A_detail_request': 53,
#  '<UNK> U_sequence_closer A_detail_request': 53,
#  '<UNK> <UNK> <UNK> A_greeting': 53,
#  'A_sequence_closer A_grant U_confirmation': 53,
#  'U_answer <ee>': 53,
#  'U_partial_request A_grant U_sequence_closer U_partial_request': 53,
#  'U_answer A_grant U_greeting': 53,
#  'A_greeting A_confirmation <UNK>': 52,
#  'A_grant U_sequence_closer A_greeting': 52,
#  'U_confirmation U_sequence_closer <UNK> U_confirmation': 52,
#  '<UNK> A_receipt A_sequence_closer': 51,
#  '<UNK> A_detail_request U_confirmation': 51,
#  '<UNK> A_sequence_closer A_sequence_closer <ee>': 51,
#  'U_confirmation U_answer A_greeting <UNK>': 51,
#  'U_answer A_request_summary A_confirmation A_detail_request': 51,
#  'A_sequence_closer A_hold_request A_greeting': 51,
#  'A_completion_check A_detail_request A_confirmation': 51,
#  'A_completion_check A_detail_request <UNK>': 50,
#  'A_detail_request U_sequence_closer U_answer': 50,
#  'U_partial_request U_answer <UNK>': 50,
#  'A_greeting A_confirmation A_grant U_confirmation': 50,
#  'U_sequence_closer U_sequence_closer <UNK> U_confirmation': 49,
#  'U_confirmation <UNK> U_partial_request': 49,
#  '<UNK> U_confirmation A_detail_request': 49,
#  'U_greeting U_partial_request A_confirmation': 49,
#  'U_answer A_sequence_closer <UNK>': 49,
#  'A_repair_initiator A_greeting': 49,
#  'U_answer A_disconfirmation U_confirmation': 48,
#  'U_confirmation U_answer A_sequence_closer A_detail_request': 48,
#  'U_sequence_closer U_answer U_confirmation': 48,
#  'U_confirmation U_answer U_greeting <UNK>': 48,
#  'A_greeting <UNK> U_confirmation': 48,
#  'U_repair_initiator U_answer': 48,
#  'A_grant U_partial_request U_answer': 48,
#  'U_sequence_closer U_answer U_greeting': 48,
#  'U_greeting U_answer U_partial_request A_detail_request': 48,
#  'U_partial_request A_hold_request A_grant <UNK>': 48,
#  'U_confirmation U_answer A_sequence_closer <ee>': 47,
#  'A_grant U_answer U_partial_request': 47,
#  'U_partial_request A_grant A_greeting': 47,
#  'A_greeting A_grant A_greeting U_greeting': 47,
#  'A_sequence_closer A_sequence_closer <UNK>': 46,
#  'U_receipt <ee>': 46,
#  'U_greeting U_answer U_confirmation': 46,
#  '<UNK> U_partial_request U_partial_request': 46,
#  'U_confirmation U_answer A_hold_request <UNK>': 46,
#  '<UNK> U_confirmation A_confirmation': 46,
#  'U_sequence_closer U_greeting U_confirmation': 46,
#  'U_confirmation U_answer U_greeting A_confirmation': 46,
#  '<UNK> U_sequence_closer U_greeting': 46,
#  'A_confirmation A_detail_request A_detail_request': 46,
#  'U_greeting A_confirmation A_detail_request': 46,
#  'U_confirmation U_partial_request U_answer': 46,
#  'U_partial_request A_repair_initiator A_detail_request': 46,
#  'U_partial_request A_greeting A_grant U_sequence_closer': 46,
#  'U_sequence_closer U_confirmation A_confirmation': 45,
#  'U_confirmation <ee>': 45,
#  'A_sequence_closer U_sequence_closer A_sequence_closer': 45,
#  'A_hold_request <UNK> U_partial_request': 45,
#  'U_sequence_closer A_sequence_closer U_confirmation': 45,
#  'A_greeting U_greeting A_greeting': 45,
#  '<UNK> <UNK> <UNK> A_greeting <UNK>': 45,
#  'A_detail_request A_grant U_confirmation': 45,
#  'A_sequence_closer U_confirmation U_partial_request': 45,
#  'U_partial_request U_sequence_closer': 45,
#  'U_partial_request A_greeting A_confirmation': 45,
#  'U_partial_request A_sequence_closer': 45,
#  'A_greeting A_grant U_confirmation U_sequence_closer': 45,
#  'U_greeting U_answer <UNK> A_greeting': 44,
#  '<UNK> A_confirmation U_confirmation': 44,
#  'U_answer A_grant <UNK> A_confirmation': 44,
#  'U_confirmation U_answer <UNK> U_greeting': 44,
#  '<UNK> A_detail_request A_detail_request': 43,
#  'A_disconfirmation U_confirmation': 43,
#  'U_confirmation U_sequence_closer A_confirmation': 43,
#  'U_greeting U_answer U_greeting A_detail_request': 43,
#  'A_greeting A_greeting <UNK>': 43,
#  'U_answer A_confirmation A_confirmation': 43,
#  '<UNK> A_greeting U_partial_request': 43,
#  'U_sequence_closer A_receipt A_sequence_closer <ee>': 43,
#  'U_sequence_closer <UNK> U_sequence_closer <UNK>': 43,
#  'A_sequence_closer A_grant U_partial_request': 43,
#  'U_sequence_closer U_sequence_closer A_sequence_closer A_sequence_closer': 43,
#  'U_partial_request A_confirmation A_grant': 43,
#  'A_sequence_closer U_greeting <UNK>': 43,
#  'U_partial_request A_grant U_sequence_closer U_greeting': 43,
#  'A_grant A_greeting U_greeting': 43,
#  'A_confirmation A_grant <UNK> A_confirmation': 42,
#  '<UNK> <UNK> A_confirmation A_detail_request': 42,
#  'U_sequence_closer U_partial_request A_detail_request A_grant': 42,
#  'U_answer A_confirmation <UNK> A_detail_request': 42,
#  '<UNK> U_greeting A_confirmation': 42,
#  'A_sequence_closer U_sequence_closer A_greeting': 42,
#  'A_sequence_closer A_hold_request U_sequence_closer': 42,
#  '<UNK> U_greeting U_sequence_closer': 42,
#  'A_sequence_closer U_greeting U_confirmation': 42,
#  'A_greeting A_grant A_greeting U_confirmation': 42,
#  'A_sequence_closer A_grant U_sequence_closer': 41,
#  'A_grant U_partial_request U_confirmation': 41,
#  'A_greeting A_confirmation A_completion_check A_detail_request': 41,
#  'A_grant U_partial_request <UNK>': 41,
#  'A_repair_initiator <UNK>': 41,
#  '<UNK> A_receipt A_sequence_closer <ee>': 41,
#  'U_greeting U_sequence_closer U_answer': 41,
#  'U_disconfirmation U_sequence_closer': 41,
#  'U_answer A_grant A_greeting': 41,
#  'U_partial_request U_greeting <UNK>': 41,
#  'A_confirmation A_grant U_sequence_closer <UNK>': 40,
#  'A_hold_request U_sequence_closer': 40,
#  'A_sequence_closer A_hold_request A_hold_request <UNK>': 40,
#  '<UNK> <UNK> U_greeting <UNK>': 40,
#  '<UNK> <UNK> U_sequence_closer <ee>': 40,
#  'U_partial_request A_grant U_confirmation U_partial_request': 40,
#  'U_answer <UNK> A_hold_request <UNK>': 39,
#  'U_sequence_closer A_confirmation A_detail_request': 39,
#  'U_confirmation <UNK> U_confirmation': 39,
#  'A_detail_request A_grant U_partial_request': 39,
#  'A_detail_request U_answer U_partial_request': 39,
#  'A_greeting A_grant A_detail_request': 39,
#  '<UNK> <UNK> U_confirmation U_partial_request': 39,
#  'U_confirmation <UNK> A_detail_request': 39,
#  '<UNK> A_greeting A_sequence_closer': 39,
#  'A_grant U_sequence_closer A_sequence_closer': 39,
#  'A_confirmation A_grant A_hold_request <UNK>': 39,
#  'A_greeting A_grant U_confirmation U_greeting': 39,
#  'U_greeting U_sequence_closer U_partial_request': 39,
#  'A_grant U_greeting U_sequence_closer': 39,
#  'U_confirmation U_answer <UNK> A_greeting A_detail_request': 38,
#  'U_answer <UNK> A_confirmation A_detail_request': 38,
#  '<UNK> U_sequence_closer U_sequence_closer <ee>': 38,
#  'U_confirmation U_sequence_closer <ee>': 38,
#  'A_confirmation A_grant A_confirmation': 38,
#  'A_detail_request U_answer <UNK> A_confirmation': 38,
#  'A_sequence_closer A_detail_request A_greeting': 38,
#  'A_grant U_confirmation A_confirmation': 38,
#  'A_detail_request A_grant A_confirmation': 38,
#  'U_sequence_closer U_greeting U_greeting': 38,
#  'A_grant <UNK> U_sequence_closer': 38,
#  'A_detail_request A_grant A_confirmation A_detail_request': 37,
#  'U_answer A_request_summary A_detail_request': 37,
#  'U_partial_request A_greeting A_detail_request': 37,
#  'U_answer <UNK> U_greeting <UNK>': 37,
#  'U_answer A_hold_request A_detail_request': 37,
#  '<UNK> A_confirmation A_greeting': 37,
#  'A_receipt A_sequence_closer U_confirmation': 37,
#  'A_detail_request A_grant A_greeting': 37,
#  'A_disconfirmation <UNK>': 36,
#  'U_sequence_closer U_sequence_closer <UNK> A_sequence_closer': 36,
#  'U_sequence_closer A_detail_request U_confirmation': 36,
#  'A_sequence_closer U_sequence_closer A_confirmation': 36,
#  'A_confirmation A_grant <UNK> A_detail_request': 36,
#  'U_sequence_closer A_receipt A_sequence_closer': 36,
#  'U_confirmation U_answer <UNK> A_greeting A_confirmation': 36,
#  'A_sequence_closer A_grant A_confirmation': 36,
#  'U_sequence_closer U_sequence_closer U_sequence_closer A_sequence_closer': 36,
#  '<UNK> <UNK> A_greeting U_confirmation': 36,
#  'U_confirmation U_answer U_confirmation A_confirmation': 36,
#  '<UNK> A_repair_initiator A_detail_request': 36,
#  'A_greeting A_grant A_greeting U_partial_request': 36,
#  'U_sequence_closer <UNK> U_sequence_closer A_greeting': 35,
#  'U_sequence_closer U_answer A_greeting': 35,
#  'U_answer A_hold_request U_confirmation': 35,
#  'U_answer A_greeting A_confirmation <UNK>': 35,
#  'U_partial_request A_request_summary A_confirmation': 35,
#  '<UNK> <UNK> A_greeting A_greeting': 35,
#  'A_confirmation A_detail_request U_partial_request': 35,
#  'U_partial_request U_answer U_partial_request': 35,
#  '<UNK> U_greeting A_greeting': 35,
#  '<UNK> <UNK> U_greeting U_confirmation': 35,
#  'A_grant U_confirmation U_confirmation': 34,
#  '<UNK> U_sequence_closer A_sequence_closer A_sequence_closer': 34,
#  'U_confirmation U_answer U_confirmation <UNK>': 34,
#  'U_partial_request A_sequence_closer A_grant': 34,
#  'A_detail_request U_answer A_greeting A_confirmation': 34,
#  'A_sequence_closer <UNK> U_sequence_closer U_sequence_closer': 34,
#  'U_greeting U_answer <UNK> A_greeting A_confirmation': 34,
#  'A_receipt A_detail_request': 34,
#  'A_sequence_closer A_detail_request U_greeting U_partial_request': 34,
#  'A_grant U_sequence_closer A_confirmation': 34,
#  'U_answer A_greeting U_partial_request': 34,
#  'U_disconfirmation U_answer A_detail_request': 33,
#  'U_sequence_closer U_partial_request A_greeting': 33,
#  'A_confirmation A_sequence_closer U_confirmation': 33,
#  'A_sequence_closer U_greeting A_detail_request': 33,
#  'U_sequence_closer U_confirmation A_detail_request': 33,
#  'U_sequence_closer A_greeting A_sequence_closer': 33,
#  'U_answer A_sequence_closer A_greeting': 33,
#  'A_sequence_closer U_confirmation A_greeting': 33,
#  '<UNK> <UNK> <ee>': 33,
#  'A_greeting A_confirmation A_grant': 33,
#  'U_greeting U_answer U_partial_request A_confirmation': 33,
#  'U_partial_request A_grant A_greeting U_confirmation': 33,
#  'A_greeting A_detail_request U_confirmation U_partial_request': 33,
#  'A_greeting A_grant A_greeting <UNK>': 33,
#  'U_partial_request A_greeting A_grant U_greeting U_confirmation': 33,
#  'U_sequence_closer U_answer U_sequence_closer A_confirmation': 32,
#  'A_detail_request U_confirmation U_partial_request': 32,
#  'A_confirmation A_sequence_closer <ee>': 32,
#  'A_repair_initiator A_confirmation': 32,
#  '<UNK> U_greeting A_detail_request': 32,
#  'A_completion_check A_detail_request A_detail_request': 32,
#  'A_confirmation A_hold_request <UNK>': 32,
#  'A_detail_request A_greeting A_detail_request': 32,
#  'U_sequence_closer <UNK> A_receipt A_sequence_closer': 32,
#  'U_confirmation U_answer <UNK> A_sequence_closer': 32,
#  'U_confirmation U_sequence_closer A_sequence_closer <ee>': 32,
#  'U_sequence_closer <UNK> A_sequence_closer <UNK>': 32,
#  'U_answer U_sequence_closer <ee>': 32,
#  'U_sequence_closer <UNK> A_greeting A_confirmation': 32,
#  'A_sequence_closer U_sequence_closer U_partial_request': 32,
#  'A_greeting A_greeting U_confirmation': 32,
#  'U_sequence_closer U_sequence_closer U_sequence_closer U_sequence_closer': 32,
#  '<UNK> U_greeting U_greeting': 32,
#  'A_confirmation A_sequence_closer <UNK> U_confirmation': 31,
#  'U_answer <UNK> U_sequence_closer <UNK>': 31,
#  'U_answer A_request_summary A_confirmation': 31,
#  '<UNK> A_detail_request <UNK>': 31,
#  'A_disconfirmation A_grant U_partial_request': 31,
#  'U_answer A_disconfirmation U_partial_request': 31,
#  'A_greeting A_grant U_sequence_closer U_greeting': 31,
#  'A_grant U_partial_request U_greeting': 31,
#  'A_detail_request A_grant A_greeting U_greeting': 31,
#  'U_confirmation U_answer U_greeting A_detail_request': 30,
#  'U_answer A_detail_request U_sequence_closer': 30,
#  '<UNK> A_greeting U_sequence_closer': 30,
#  'A_greeting A_detail_request U_greeting U_partial_request U_answer A_detail_request': 30,
#  'A_detail_request U_answer <UNK> A_detail_request': 30,
#  'A_confirmation A_sequence_closer A_greeting': 30,
#  'U_answer U_partial_request <UNK>': 30,
#  'U_confirmation U_answer A_sequence_closer U_confirmation': 30,
#  '<UNK> A_greeting A_greeting <UNK>': 30,
#  'U_partial_request A_disconfirmation A_grant': 30,
#  'A_sequence_closer A_completion_check A_detail_request U_confirmation': 30,
#  'U_greeting U_partial_request A_detail_request': 30,
#  'U_answer U_sequence_closer <UNK>': 29,
#  'U_partial_request <UNK> A_confirmation': 29,
#  'U_partial_request A_grant U_confirmation <UNK>': 29,
#  'U_answer U_partial_request A_detail_request': 29,
#  'U_confirmation U_answer U_partial_request A_confirmation': 29,
#  'U_confirmation U_answer A_sequence_closer A_greeting': 29,
#  'U_sequence_closer U_greeting A_detail_request': 29,
#  'U_sequence_closer A_hold_request U_confirmation': 29,
#  'A_greeting A_grant U_confirmation <UNK>': 29,
#  'U_sequence_closer <UNK> A_sequence_closer A_sequence_closer <ee>': 29,
#  'U_sequence_closer A_greeting U_partial_request': 29,
#  '<UNK> A_detail_request U_partial_request': 29,
#  'U_answer <UNK> A_detail_request A_detail_request': 29,
#  'A_confirmation A_detail_request U_confirmation': 29,
#  'A_grant A_greeting <UNK> U_partial_request': 29,
#  'U_sequence_closer U_greeting A_greeting': 29,
#  'U_sequence_closer A_detail_request U_partial_request': 29,
#  'U_answer U_greeting U_sequence_closer': 29,
#  '<UNK> U_confirmation U_greeting': 29,
#  'A_grant U_sequence_closer U_confirmation': 29,
#  'A_request_summary A_request_summary A_confirmation A_detail_request': 29,
#  'A_detail_request A_sequence_closer': 28,
#  'U_answer A_hold_request A_hold_request <UNK>': 28,
#  'U_receipt U_sequence_closer <ee>': 28,
#  '<UNK> A_sequence_closer A_greeting': 28,
#  '<UNK> <UNK> <UNK> U_greeting': 28,
#  '<UNK> <UNK> A_confirmation <UNK>': 28,
#  'A_confirmation A_sequence_closer U_sequence_closer <ee>': 28,
#  '<UNK> <UNK> <UNK> U_confirmation <UNK>': 28,
#  'A_confirmation <UNK> U_partial_request': 28,
#  '<UNK> A_confirmation U_sequence_closer': 28,
#  'U_confirmation U_sequence_closer U_confirmation': 28,
#  'A_confirmation U_confirmation <UNK>': 28,
#  'A_sequence_closer A_hold_request A_confirmation': 28,
#  'A_confirmation A_grant <UNK> U_greeting': 28,
#  'U_sequence_closer U_partial_request A_greeting A_confirmation A_grant': 28,
#  'A_grant U_greeting <UNK>': 28,
#  'U_partial_request A_greeting A_grant A_greeting': 28,
#  'A_sequence_closer U_sequence_closer <UNK> U_confirmation': 27,
#  'U_sequence_closer U_confirmation U_greeting': 27,
#  'U_answer <UNK> A_sequence_closer <ee>': 27,
#  'U_sequence_closer <UNK> A_receipt A_sequence_closer <ee>': 27,
#  '<UNK> A_greeting A_confirmation <UNK>': 27,
#  'U_confirmation U_answer A_greeting A_sequence_closer': 27,
#  'U_sequence_closer A_greeting U_sequence_closer': 27,
#  '<UNK> A_request_summary A_confirmation A_detail_request': 27,
#  'U_sequence_closer <UNK> U_sequence_closer U_sequence_closer': 27,
#  '<UNK> A_greeting U_greeting': 27,
#  'A_hold_request A_grant A_greeting': 27,
#  'U_answer U_greeting A_greeting': 27,
#  'A_greeting A_detail_request A_grant': 27,
#  'U_disconfirmation <UNK>': 27,
#  'U_sequence_closer <UNK> A_sequence_closer A_sequence_closer': 27,
#  'A_greeting A_detail_request <UNK>': 27,
#  'U_answer A_hold_request A_grant': 27,
#  'A_confirmation A_greeting A_detail_request': 27,
#  'U_answer A_grant <UNK> A_detail_request': 27,
#  'U_sequence_closer U_sequence_closer <UNK> U_sequence_closer': 27,
#  'A_sequence_closer U_greeting A_greeting': 27,
#  'U_confirmation U_sequence_closer U_greeting U_partial_request': 27,
#  '<UNK> <UNK> U_sequence_closer A_greeting': 26,
#  'A_detail_request <UNK> U_partial_request': 26,
#  'U_answer A_detail_request <UNK>': 26,
#  'U_confirmation U_answer A_sequence_closer <UNK>': 26,
#  'U_confirmation U_answer U_sequence_closer <UNK>': 26,
#  'U_partial_request A_grant A_hold_request <UNK>': 26,
#  'U_partial_request A_confirmation A_detail_request': 26,
#  'U_greeting U_greeting A_confirmation': 26,
#  'A_greeting A_confirmation U_confirmation': 26,
#  'U_answer A_confirmation U_partial_request': 26,
#  'A_grant A_hold_request U_confirmation': 26,
#  '<UNK> U_sequence_closer U_confirmation': 26,
#  '<UNK> <UNK> U_sequence_closer U_partial_request': 26,
#  'U_sequence_closer <UNK> U_sequence_closer A_confirmation': 26,
#  'A_greeting U_confirmation <UNK>': 26,
#  'A_sequence_closer A_hold_request A_greeting <UNK>': 26,
#  'A_sequence_closer A_confirmation A_greeting': 26,
#  'A_disconfirmation A_sequence_closer A_detail_request': 26,
#  'U_greeting A_greeting <UNK> A_confirmation': 26,
#  'U_sequence_closer <UNK> U_greeting U_confirmation': 26,
#  'A_greeting U_confirmation U_partial_request': 26,
#  'U_sequence_closer A_confirmation U_confirmation': 26,
#  'A_completion_check A_detail_request A_sequence_closer': 26,
#  '<UNK> U_partial_request U_confirmation': 26,
#  'A_grant A_greeting U_sequence_closer': 26,
#  'A_sequence_closer A_greeting U_partial_request': 26,
#  'U_partial_request A_grant U_confirmation U_greeting': 26,
#  'A_sequence_closer A_hold_request A_grant': 26,
#  'U_answer U_sequence_closer A_detail_request': 25,
#  'U_answer <UNK> U_sequence_closer U_partial_request': 25,
#  'U_answer <UNK> A_greeting U_confirmation': 25,
#  'U_greeting U_answer A_repair_initiator A_detail_request': 25,
#  'A_grant U_sequence_closer A_detail_request': 25,
#  'A_receipt <UNK> A_sequence_closer': 25,
#  'U_greeting U_answer <UNK> U_greeting <UNK>': 25,
#  'U_confirmation U_answer A_detail_request U_confirmation': 25,
#  'U_confirmation U_answer A_detail_request A_detail_request': 25,
#  'A_detail_request U_answer A_greeting': 25,
#  'A_sequence_closer A_greeting U_sequence_closer': 25,
#  '<UNK> <UNK> U_sequence_closer A_sequence_closer <ee>': 25,
#  '<UNK> U_confirmation A_greeting': 25,
#  'A_request_summary U_sequence_closer': 25,
#  'A_sequence_closer A_hold_request <UNK> A_detail_request': 25,
#  '<UNK> U_confirmation U_confirmation': 25,
#  'A_confirmation A_confirmation <UNK>': 25,
#  'U_sequence_closer <UNK> U_sequence_closer U_partial_request': 25,
#  'U_greeting U_answer U_greeting A_greeting': 25,
#  '<UNK> <UNK> U_sequence_closer A_confirmation': 25,
#  'U_greeting U_answer U_partial_request <UNK>': 25,
#  'A_completion_check A_detail_request A_grant': 25,
#  'U_greeting A_confirmation <UNK>': 25,
#  'A_greeting A_confirmation A_grant A_detail_request': 25,
#  'U_partial_request A_greeting A_confirmation A_grant U_sequence_closer U_partial_request': 25,
#  '<UNK> <UNK> U_sequence_closer U_sequence_closer': 25,
#  'A_grant U_greeting U_confirmation U_partial_request': 25,
#  'U_partial_request A_greeting A_confirmation A_grant U_sequence_closer': 25,
#  'U_sequence_closer U_sequence_closer A_sequence_closer <UNK>': 25,
#  'U_greeting U_sequence_closer <ee>': 24,
#  'U_confirmation U_answer A_completion_check A_detail_request': 24,
#  '<UNK> A_detail_request A_confirmation': 24,
#  'U_answer A_hold_request A_greeting': 24,
#  'A_grant A_confirmation <UNK>': 24,
#  'A_disconfirmation A_detail_request': 24,
#  'A_detail_request A_confirmation A_greeting': 24,
#  'U_answer A_confirmation U_sequence_closer': 24,
#  'U_confirmation U_answer U_sequence_closer <ee>': 24,
#  'A_detail_request A_grant U_greeting': 24,
#  'U_greeting U_partial_request U_greeting': 24,
#  'U_sequence_closer A_greeting U_greeting': 24,
#  'A_confirmation U_sequence_closer A_detail_request': 24,
#  '<UNK> U_partial_request A_greeting': 24,
#  '<UNK> U_partial_request U_greeting': 24,
#  'U_greeting <UNK> U_greeting': 24,
#  'A_greeting A_grant U_sequence_closer U_sequence_closer': 24,
#  'A_grant U_partial_request A_confirmation': 23,
#  'U_answer A_greeting A_sequence_closer': 23,
#  'A_hold_request <UNK> A_detail_request': 23,
#  'U_answer <UNK> A_request_summary A_confirmation A_detail_request': 23,
#  'A_completion_check A_detail_request U_sequence_closer': 23,
#  'A_hold_request A_greeting U_confirmation': 23,
#  '<UNK> <UNK> U_partial_request <UNK>': 23,
#  'U_greeting U_confirmation <UNK>': 23,
#  'A_sequence_closer A_greeting A_sequence_closer': 23,
#  'U_confirmation <UNK> A_greeting': 23,
#  'A_confirmation A_grant U_sequence_closer A_detail_request': 23,
#  'U_confirmation U_partial_request A_confirmation': 23,
#  '<UNK> A_hold_request U_confirmation': 23,
#  'U_answer A_sequence_closer U_confirmation': 23,
#  'A_confirmation A_grant U_sequence_closer A_greeting': 23,
#  'U_confirmation U_sequence_closer A_greeting U_confirmation': 23,
#  'A_greeting A_confirmation A_grant U_sequence_closer': 23,
#  'U_sequence_closer A_receipt <ee>': 23,
#  'A_confirmation A_grant A_greeting <UNK>': 23,
#  'A_request_summary U_confirmation': 23,
#  'U_greeting A_sequence_closer': 23,
#  'A_detail_request U_greeting': 23,
#  'A_greeting A_grant U_greeting U_confirmation U_partial_request': 23,
#  'A_sequence_closer <UNK> A_detail_request A_confirmation': 22,
#  'U_sequence_closer U_partial_request A_sequence_closer': 22,
#  'A_request_summary A_grant': 22,
#  'A_sequence_closer A_hold_request <UNK> U_partial_request': 22,
#  'U_sequence_closer U_confirmation A_greeting': 22,
#  'A_sequence_closer A_sequence_closer A_detail_request': 22,
#  'U_partial_request A_hold_request A_grant A_greeting': 22,
#  'A_detail_request U_answer A_greeting A_detail_request': 22,
#  'A_request_summary <UNK>': 22,
#  'A_confirmation A_greeting <UNK>': 22,
#  'U_confirmation A_greeting A_confirmation': 22,
#  '<UNK> <UNK> U_confirmation A_confirmation': 22,
#  'A_sequence_closer A_completion_check A_detail_request U_partial_request': 22,
#  'U_sequence_closer A_sequence_closer A_greeting': 22,
#  'A_greeting U_greeting U_confirmation': 22,
#  'U_sequence_closer U_answer U_confirmation <UNK>': 22,
#  'U_answer <UNK> U_sequence_closer A_greeting': 22,
#  'A_hold_request A_hold_request <UNK>': 22,
#  'U_partial_request U_partial_request U_partial_request': 22,
#  'A_sequence_closer U_partial_request A_detail_request': 22,
#  'U_confirmation U_answer A_detail_request U_partial_request': 22,
#  'A_greeting A_grant U_greeting U_sequence_closer U_partial_request': 22,
#  'U_answer U_partial_request U_partial_request': 22,
#  'U_sequence_closer U_sequence_closer U_greeting U_sequence_closer': 22,
#  'U_answer A_detail_request U_greeting': 22,
#  'U_sequence_closer <UNK> U_greeting <UNK>': 22,
#  'U_greeting U_answer U_greeting U_greeting': 22,
#  'A_greeting A_grant U_partial_request U_greeting': 21,
#  'U_sequence_closer <UNK> A_sequence_closer U_sequence_closer': 21,
#  'A_greeting A_detail_request U_confirmation': 21,
#  'U_answer <UNK> A_detail_request U_confirmation': 21,
#  'A_greeting A_confirmation A_greeting': 21,
#  '<UNK> <UNK> U_partial_request A_confirmation': 21,
#  'U_confirmation U_partial_request <UNK>': 21,
#  'U_sequence_closer A_sequence_closer A_detail_request': 21,
#  'U_answer A_detail_request A_confirmation': 21,
#  'U_sequence_closer U_sequence_closer <UNK> A_confirmation': 21,
#  '<UNK> A_sequence_closer A_detail_request': 21,
#  'U_answer U_confirmation A_detail_request': 21,
#  '<UNK> <UNK> A_sequence_closer <ee>': 21,
#  'U_partial_request A_grant A_greeting <UNK>': 21,
#  'U_sequence_closer U_greeting A_sequence_closer': 21,
#  'U_sequence_closer U_partial_request A_repair_initiator A_detail_request': 21,
#  'U_sequence_closer <UNK> U_sequence_closer A_sequence_closer': 21,
#  'A_grant <ee>': 21,
#  '<UNK> U_sequence_closer A_sequence_closer A_sequence_closer <ee>': 21,
#  'U_partial_request A_confirmation A_detail_request A_grant': 21,
#  'A_confirmation <UNK> A_greeting': 21,
#  'U_confirmation U_greeting <UNK>': 21,
#  'A_grant U_greeting U_sequence_closer U_partial_request': 21,
#  'U_answer A_disconfirmation <UNK>': 20,
#  'U_sequence_closer U_answer A_receipt': 20,
#  'U_answer <UNK> U_sequence_closer <ee>': 20,
#  '<UNK> <UNK> U_greeting A_confirmation': 20,
#  'U_confirmation U_answer A_confirmation U_confirmation': 20,
#  '<UNK> <UNK> A_request_summary A_confirmation A_detail_request': 20,
#  '<UNK> <UNK> U_sequence_closer A_sequence_closer': 20,
#  'A_repair_initiator A_detail_request A_grant': 20,
#  'A_sequence_closer <UNK> A_detail_request A_detail_request': 20,
#  'U_confirmation U_answer <UNK> U_sequence_closer U_sequence_closer': 20,
#  'U_confirmation A_greeting U_confirmation': 20,
#  'A_confirmation U_sequence_closer <UNK>': 20,
#  'A_grant <UNK> A_greeting': 20,
#  'U_sequence_closer A_confirmation U_sequence_closer': 20,
#  'A_greeting A_detail_request A_detail_request': 20,
#  'A_receipt U_confirmation': 20,
#  'U_answer A_confirmation A_greeting A_detail_request': 20,
#  'U_confirmation U_partial_request U_partial_request': 20,
#  'U_sequence_closer U_sequence_closer U_confirmation': 20,
#  'A_sequence_closer <UNK> A_sequence_closer U_sequence_closer': 20,
#  'U_partial_request A_grant U_sequence_closer <UNK>': 20,
#  'A_confirmation A_grant A_greeting U_confirmation': 20,
#  'U_sequence_closer U_answer U_sequence_closer <ee>': 20,
#  'U_partial_request A_repair_initiator A_greeting': 20,
#  'U_greeting U_answer A_greeting <UNK>': 20,
#  'U_greeting U_confirmation U_answer': 20,
#  'A_greeting A_confirmation A_grant U_greeting': 20,
#  'U_answer A_confirmation U_greeting': 20,
#  'U_greeting U_answer A_sequence_closer A_detail_request': 20,
#  'U_answer U_greeting U_greeting': 20,
#  'U_partial_request A_greeting A_grant <UNK> U_confirmation': 20,
#  'U_partial_request U_answer U_greeting': 20,
#  'U_confirmation U_greeting U_sequence_closer': 20,
#  'A_greeting A_grant U_partial_request U_partial_request': 20,
#  'U_partial_request A_grant U_greeting U_greeting': 20,
#  'A_grant <UNK> A_sequence_closer': 19,
#  '<UNK> A_receipt <ee>': 19,
#  'U_confirmation U_answer <UNK> U_sequence_closer <UNK>': 19,
#  'U_confirmation U_answer A_greeting U_sequence_closer': 19,
#  'U_sequence_closer U_answer <ee>': 19,
#  '<UNK> U_sequence_closer <UNK> U_confirmation': 19,
#  'A_sequence_closer <UNK> A_sequence_closer U_confirmation': 19,
#  'A_confirmation A_sequence_closer U_sequence_closer': 19,
#  'U_answer A_confirmation A_completion_check A_detail_request': 19,
#  'A_hold_request A_greeting <UNK>': 19,
#  'U_confirmation U_answer A_repair_initiator A_detail_request': 19,
#  'U_answer A_greeting U_sequence_closer': 19,
#  'A_confirmation A_confirmation A_detail_request': 19,
#  'U_sequence_closer A_confirmation A_greeting': 19,
#  'U_greeting U_answer A_sequence_closer <ee>': 19,
#  '<UNK> <UNK> <UNK> U_sequence_closer <UNK>': 19,
#  '<UNK> <UNK> <UNK> A_sequence_closer': 19,
#  'U_greeting U_answer A_greeting U_confirmation': 19,
#  'U_greeting U_answer A_hold_request <UNK>': 19,
#  '<UNK> U_greeting U_greeting <UNK>': 19,
#  'U_repair_initiator <UNK>': 19,
#  ...}

# %%
#getting some ideas on statistics. min and max sequence len.
#see without grouping histrogram/bar of counts per key 
#also group counts per len to seemost frequent sizes of sequences
#plot stacked bar como em titanic. cada bar é uma seq len, cada stacked value inside é a sequencia. 
####pra isso criar nova coluna com a len de cada

seq_to_plot = []

for key, value in sorted_d.items():
    seq_to_plot.append(key.split(' '))
    
max_len = len(max(seq_to_plot, key=len))
min_len = len(min(seq_to_plot, key=len))

seq_sizes = {}

for seq in seq_to_plot:
    for leng in range(max_len):
        if len(seq) == leng:
            seq_sizes[leng] = seq_sizes[leng] + sorted_d.get(' '.join(seq)) if leng in seq_sizes else sorted_d.get(' '.join(seq))

print('minimum len: '+ str(min_len))
print('maximum len: '+ str(max_len))
print('counts of number of sequences of each len (ranking): ' + str(sorted(seq_sizes.items(), key=operator.itemgetter(1),reverse=True)))
seq_sizes #shows as key the sequence length and value the sum of all sequences of same length
sorted_d # all sequences with its individual counts

# #to see only sequences of specific len I can use the below:
# for e, seq in enumerate(seq_to_plot):
#     if len(seq) ==10:
#         print(seq, sorted_d.get(' '.join(seq)))
# Out:
# minimum len: 1
# maximum len: 10
# counts of number of sequences of each len (ranking): [(2, 117695), (3, 80565), (4, 27296), (1, 17288), (5, 6611), (6, 1535), (7, 265), (8, 36), (9, 3)]
# {'': 17288,
#  'A_sequence_closer A_detail_request': 8476,
#  'U_answer A_confirmation': 7806,
#  'U_answer A_detail_request': 5684,
#  'U_sequence_closer U_partial_request': 4760,
#  'U_sequence_closer <ee>': 4642,
#  'A_grant U_confirmation': 4561,
#  'A_greeting A_detail_request': 4526,
#  'A_completion_check A_detail_request': 3644,
#  'A_greeting A_greeting A_detail_request': 3363,
#  'A_sequence_closer <UNK>': 3048,
#  'A_grant U_partial_request': 2920,
#  '<UNK> U_confirmation': 2450,
#  'U_sequence_closer <UNK>': 2380,
#  'U_answer <UNK>': 2303,
#  '<UNK> A_confirmation': 2215,
#  'A_sequence_closer <ee>': 2200,
#  'U_confirmation U_answer A_confirmation': 1902,
#  'U_greeting U_partial_request': 1707,
#  'A_grant <UNK>': 1681,
#  '<UNK> A_detail_request': 1621,
#  'A_greeting A_grant U_confirmation': 1573,
#  'A_confirmation A_detail_request': 1504,
#  'A_greeting A_grant U_partial_request': 1488,
#  '<UNK> <UNK>': 1338,
#  'U_greeting U_answer A_confirmation': 1335,
#  '<UNK> U_partial_request': 1311,
#  'U_partial_request A_confirmation': 1290,
#  '<UNK> <ee>': 1224,
#  'U_greeting U_answer <UNK>': 1188,
#  'U_confirmation U_answer A_detail_request': 1185,
#  'U_confirmation U_answer <UNK>': 1172,
#  'U_greeting <UNK>': 1135,
#  'A_sequence_closer A_greeting': 1112,
#  'U_sequence_closer U_greeting': 1095,
#  'U_answer A_greeting': 1087,
#  'A_sequence_closer U_confirmation': 1063,
#  'U_sequence_closer U_answer': 1055,
#  'A_receipt A_sequence_closer <ee>': 1006,
#  'A_grant U_sequence_closer': 936,
#  'U_greeting U_confirmation': 915,
#  'U_sequence_closer A_confirmation': 898,
#  'U_greeting A_greeting': 896,
#  'A_greeting A_greeting': 895,
#  'A_sequence_closer A_completion_check A_detail_request': 894,
#  'U_greeting U_answer A_detail_request': 888,
#  '<UNK> A_greeting': 880,
#  'U_sequence_closer <UNK> U_confirmation': 873,
#  'U_sequence_closer U_sequence_closer': 866,
#  'A_grant U_greeting': 857,
#  'U_partial_request A_grant U_confirmation': 838,
#  'A_grant U_answer': 831,
#  'U_sequence_closer A_sequence_closer <ee>': 815,
#  'A_confirmation <UNK>': 795,
#  'U_sequence_closer A_detail_request': 791,
#  'U_answer A_grant': 773,
#  'U_sequence_closer U_sequence_closer <ee>': 772,
#  'A_greeting A_grant U_greeting U_partial_request': 752,
#  'A_greeting <UNK>': 745,
#  'U_answer <UNK> A_detail_request': 713,
#  'U_answer <UNK> A_confirmation': 706,
#  'U_sequence_closer A_greeting': 664,
#  'U_confirmation <UNK>': 663,
#  'A_confirmation A_grant U_confirmation': 655,
#  'U_sequence_closer U_greeting U_partial_request': 641,
#  'U_answer A_greeting A_confirmation': 637,
#  'U_partial_request A_grant U_partial_request': 637,
#  'A_detail_request A_confirmation': 634,
#  '<UNK> <UNK> U_confirmation': 632,
#  'A_sequence_closer U_sequence_closer <ee>': 627,
#  'A_sequence_closer A_sequence_closer': 622,
#  'U_answer A_greeting A_detail_request': 617,
#  '<UNK> U_greeting': 611,
#  'A_receipt A_sequence_closer': 605,
#  'A_sequence_closer <UNK> U_confirmation': 597,
#  'U_greeting U_answer': 590,
#  'U_confirmation U_partial_request': 586,
#  '<UNK> U_sequence_closer': 577,
#  'U_answer A_confirmation A_detail_request': 571,
#  'U_greeting U_answer U_partial_request': 569,
#  'A_sequence_closer U_sequence_closer': 567,
#  'A_detail_request A_grant': 563,
#  'A_sequence_closer <UNK> A_confirmation': 556,
#  'A_confirmation A_completion_check A_detail_request': 552,
#  'A_detail_request U_partial_request': 547,
#  'A_detail_request A_detail_request': 546,
#  '<UNK> A_sequence_closer': 534,
#  'A_confirmation A_grant <UNK>': 528,
#  'A_greeting A_grant U_greeting': 526,
#  '<UNK> A_sequence_closer <ee>': 518,
#  'A_greeting A_confirmation': 506,
#  '<UNK> <UNK> A_confirmation': 499,
#  'U_partial_request A_grant U_greeting': 480,
#  'U_partial_request U_answer': 472,
#  'U_greeting U_answer <UNK> A_confirmation': 469,
#  'A_greeting U_greeting': 463,
#  'A_sequence_closer <UNK> A_detail_request': 459,
#  'U_answer <UNK> U_confirmation': 458,
#  'U_confirmation U_answer': 456,
#  'A_grant <UNK> U_confirmation': 448,
#  'U_answer U_partial_request': 447,
#  'A_sequence_closer A_grant': 445,
#  'A_confirmation A_grant U_partial_request': 443,
#  'A_sequence_closer U_partial_request': 436,
#  'A_hold_request <UNK>': 432,
#  '<UNK> U_sequence_closer <ee>': 428,
#  'A_sequence_closer A_confirmation': 427,
#  'A_greeting U_confirmation': 420,
#  'A_greeting A_detail_request U_partial_request': 419,
#  'U_sequence_closer A_sequence_closer': 417,
#  'A_receipt <ee>': 416,
#  'A_grant U_greeting U_partial_request': 414,
#  'A_grant <UNK> U_partial_request': 412,
#  'U_answer U_sequence_closer': 408,
#  'U_partial_request U_partial_request': 403,
#  'U_greeting U_answer <UNK> A_detail_request': 399,
#  'U_sequence_closer <UNK> A_confirmation': 398,
#  'A_greeting A_grant <UNK>': 395,
#  'U_partial_request A_grant <UNK>': 394,
#  'U_partial_request A_detail_request': 388,
#  'A_hold_request A_grant': 382,
#  'U_answer A_grant U_confirmation': 373,
#  '<UNK> <UNK> A_detail_request': 370,
#  'A_sequence_closer A_sequence_closer <ee>': 370,
#  'U_sequence_closer <UNK> U_partial_request': 365,
#  'U_confirmation U_answer U_partial_request': 358,
#  'U_sequence_closer U_confirmation': 357,
#  'U_partial_request U_greeting': 353,
#  'U_partial_request A_greeting': 346,
#  'U_partial_request <UNK>': 344,
#  'A_detail_request U_answer A_confirmation': 343,
#  'A_detail_request U_confirmation': 339,
#  'A_sequence_closer A_detail_request U_partial_request': 338,
#  'U_confirmation U_answer <UNK> A_confirmation': 337,
#  'A_grant U_greeting U_confirmation': 335,
#  'U_greeting A_confirmation': 333,
#  'A_sequence_closer A_detail_request U_confirmation': 332,
#  'U_answer A_sequence_closer': 331,
#  'U_answer A_grant U_partial_request': 328,
#  'U_request_summary U_confirmation': 328,
#  '<UNK> <UNK> <UNK>': 327,
#  'U_sequence_closer U_sequence_closer A_sequence_closer <ee>': 323,
#  '<UNK> <UNK> U_partial_request': 323,
#  '<UNK> A_greeting A_detail_request': 319,
#  'A_grant A_greeting': 317,
#  'A_detail_request <UNK>': 314,
#  'A_confirmation U_confirmation': 305,
#  'U_answer A_confirmation <UNK>': 302,
#  'U_confirmation A_confirmation': 298,
#  'A_sequence_closer A_hold_request <UNK>': 292,
#  'A_greeting A_grant U_greeting U_confirmation': 289,
#  'U_partial_request U_answer A_greeting': 287,
#  'U_confirmation U_answer <UNK> A_detail_request': 286,
#  'A_sequence_closer A_detail_request A_detail_request': 286,
#  'A_sequence_closer U_greeting': 285,
#  'U_partial_request A_grant U_greeting U_partial_request': 282,
#  'A_confirmation A_greeting': 277,
#  'A_greeting U_partial_request': 268,
#  'A_repair_initiator A_detail_request': 267,
#  'U_confirmation U_answer U_sequence_closer': 265,
#  'A_grant A_detail_request': 265,
#  'U_confirmation U_answer <UNK> U_confirmation': 264,
#  'U_sequence_closer U_sequence_closer U_sequence_closer': 256,
#  'U_greeting U_sequence_closer': 255,
#  'U_greeting U_greeting': 250,
#  'U_greeting U_answer A_greeting': 249,
#  'A_detail_request A_greeting': 242,
#  'U_sequence_closer U_answer <UNK>': 241,
#  'U_confirmation U_answer A_greeting': 241,
#  'U_partial_request A_greeting A_grant U_confirmation': 239,
#  'U_sequence_closer <UNK> A_detail_request': 237,
#  'A_confirmation A_grant A_detail_request': 237,
#  'U_greeting U_answer U_greeting': 234,
#  'A_confirmation A_grant U_sequence_closer': 231,
#  'A_grant U_answer A_detail_request': 230,
#  'U_greeting <UNK> A_greeting': 227,
#  'A_greeting U_greeting <UNK>': 226,
#  'U_answer A_grant <UNK>': 225,
#  '<UNK> A_greeting <UNK>': 225,
#  'A_receipt <UNK>': 224,
#  'A_greeting A_grant U_sequence_closer': 222,
#  'U_greeting U_partial_request A_greeting': 221,
#  'U_answer <UNK> U_partial_request': 219,
#  'U_sequence_closer <UNK> U_sequence_closer': 218,
#  'A_greeting A_grant A_greeting': 217,
#  'A_sequence_closer A_grant <UNK>': 213,
#  'U_confirmation U_answer A_sequence_closer': 211,
#  'A_confirmation A_grant': 211,
#  '<UNK> <UNK> A_greeting': 205,
#  'A_grant U_confirmation U_partial_request': 204,
#  'A_grant U_sequence_closer U_partial_request': 201,
#  'U_sequence_closer <UNK> A_sequence_closer <ee>': 201,
#  '<UNK> <UNK> A_greeting A_detail_request': 200,
#  'U_answer U_greeting': 199,
#  'A_detail_request U_answer A_detail_request': 189,
#  '<UNK> <UNK> <UNK> U_confirmation': 187,
#  '<UNK> A_greeting A_confirmation': 187,
#  'U_disconfirmation U_answer': 185,
#  'U_confirmation A_detail_request': 180,
#  'U_sequence_closer <UNK> <ee>': 180,
#  'U_sequence_closer U_partial_request U_partial_request': 179,
#  'A_detail_request A_confirmation A_detail_request': 176,
#  'A_greeting A_grant <UNK> U_partial_request': 176,
#  'A_grant U_confirmation U_sequence_closer': 172,
#  'U_answer U_confirmation': 171,
#  'A_greeting U_greeting A_confirmation': 171,
#  'U_sequence_closer <UNK> U_greeting': 170,
#  'A_request_summary A_confirmation A_detail_request': 170,
#  'U_confirmation U_answer U_greeting': 170,
#  'U_greeting U_answer A_greeting A_detail_request': 169,
#  '<UNK> A_confirmation A_detail_request': 169,
#  'A_sequence_closer <UNK> U_partial_request': 168,
#  'U_greeting U_answer <UNK> U_partial_request': 167,
#  'U_partial_request A_hold_request A_grant': 166,
#  'U_partial_request A_greeting A_confirmation A_grant U_partial_request': 166,
#  'A_sequence_closer <UNK> U_sequence_closer': 165,
#  'U_greeting U_answer A_greeting A_confirmation': 165,
#  'U_sequence_closer <UNK> A_sequence_closer': 162,
#  '<UNK> U_sequence_closer <UNK>': 161,
#  'U_sequence_closer U_sequence_closer <UNK>': 161,
#  'A_sequence_closer <UNK> A_greeting': 160,
#  'U_confirmation U_answer A_greeting A_confirmation': 159,
#  'A_sequence_closer A_greeting A_detail_request': 158,
#  'U_confirmation A_greeting': 158,
#  'U_greeting A_detail_request': 158,
#  'A_detail_request U_partial_request U_answer': 157,
#  'U_sequence_closer U_answer U_sequence_closer': 156,
#  'U_confirmation U_greeting': 156,
#  'U_partial_request A_greeting A_confirmation A_grant U_confirmation': 156,
#  'U_sequence_closer U_answer A_detail_request': 155,
#  'U_confirmation U_sequence_closer': 155,
#  'A_confirmation U_sequence_closer': 154,
#  'U_confirmation U_answer A_greeting A_detail_request': 154,
#  'U_answer <UNK> A_greeting': 153,
#  'U_answer A_confirmation A_greeting': 152,
#  'U_sequence_closer A_sequence_closer A_sequence_closer <ee>': 152,
#  'A_grant U_confirmation <UNK>': 151,
#  'A_sequence_closer A_detail_request A_confirmation': 151,
#  'U_sequence_closer A_greeting U_confirmation': 149,
#  'U_greeting <UNK> A_confirmation': 149,
#  'A_detail_request U_sequence_closer': 149,
#  'A_detail_request U_greeting U_partial_request': 146,
#  'A_receipt A_sequence_closer A_sequence_closer <ee>': 146,
#  '<UNK> A_confirmation <UNK>': 145,
#  'U_sequence_closer U_answer A_sequence_closer': 144,
#  'U_sequence_closer U_sequence_closer A_sequence_closer': 144,
#  'U_greeting A_greeting A_detail_request': 144,
#  'A_disconfirmation A_grant': 142,
#  '<UNK> U_sequence_closer U_sequence_closer': 142,
#  'A_sequence_closer <UNK> <ee>': 142,
#  'A_grant <UNK> A_confirmation': 141,
#  '<UNK> U_confirmation <UNK>': 140,
#  'U_partial_request A_greeting A_grant U_greeting U_partial_request': 139,
#  'A_sequence_closer A_grant A_detail_request': 138,
#  'A_receipt U_sequence_closer': 137,
#  'U_sequence_closer U_answer U_partial_request': 137,
#  'A_greeting U_greeting <UNK> A_confirmation': 136,
#  '<UNK> A_greeting A_greeting': 136,
#  '<UNK> <UNK> A_greeting <UNK>': 136,
#  'A_sequence_closer U_confirmation <UNK>': 135,
#  'U_greeting A_greeting A_greeting': 135,
#  'U_sequence_closer U_partial_request A_detail_request': 135,
#  'A_sequence_closer A_sequence_closer A_sequence_closer': 135,
#  'A_confirmation A_grant <UNK> U_confirmation': 133,
#  'U_sequence_closer U_sequence_closer A_confirmation': 132,
#  'U_partial_request A_greeting A_confirmation A_grant': 132,
#  'U_answer A_hold_request <UNK>': 131,
#  'U_sequence_closer U_partial_request A_confirmation': 131,
#  'U_answer A_sequence_closer <ee>': 131,
#  'A_greeting A_detail_request U_greeting U_partial_request': 130,
#  'U_partial_request A_grant U_sequence_closer': 130,
#  'U_sequence_closer U_sequence_closer U_partial_request': 128,
#  '<UNK> <UNK> U_greeting': 128,
#  'U_answer A_sequence_closer A_detail_request': 127,
#  'U_sequence_closer U_sequence_closer A_greeting': 127,
#  'U_sequence_closer <UNK> A_greeting': 127,
#  'A_sequence_closer A_detail_request U_sequence_closer': 126,
#  'A_sequence_closer A_hold_request U_confirmation': 126,
#  'A_grant U_answer <UNK>': 125,
#  'U_sequence_closer A_greeting <UNK>': 125,
#  '<UNK> <UNK> <UNK> A_confirmation': 125,
#  'A_confirmation <UNK> A_confirmation': 125,
#  'U_sequence_closer U_confirmation <UNK>': 124,
#  'U_greeting <UNK> A_detail_request': 124,
#  'U_sequence_closer U_partial_request <UNK>': 124,
#  'U_partial_request A_greeting A_grant U_greeting': 124,
#  'U_confirmation U_sequence_closer U_partial_request': 123,
#  'A_grant <UNK> U_greeting': 123,
#  'U_answer U_greeting A_confirmation': 122,
#  'A_sequence_closer U_sequence_closer <UNK>': 122,
#  'U_partial_request A_greeting A_grant U_partial_request': 122,
#  'A_sequence_closer A_greeting <UNK>': 120,
#  'A_detail_request A_grant <UNK>': 119,
#  'A_request_summary A_confirmation': 119,
#  '<UNK> U_greeting <UNK>': 119,
#  'A_hold_request A_grant <UNK>': 117,
#  'U_greeting U_answer <UNK> U_greeting': 117,
#  'U_confirmation U_sequence_closer <UNK>': 115,
#  'A_detail_request U_greeting U_confirmation': 114,
#  '<UNK> <UNK> <UNK> A_detail_request': 113,
#  'A_greeting A_grant <UNK> U_confirmation': 113,
#  'U_sequence_closer A_greeting A_detail_request': 111,
#  'A_greeting <UNK> A_confirmation': 110,
#  '<UNK> <UNK> <UNK> U_partial_request': 108,
#  'U_sequence_closer U_greeting <UNK>': 107,
#  'A_grant U_sequence_closer <ee>': 106,
#  'U_answer U_sequence_closer A_confirmation': 106,
#  'U_partial_request U_confirmation': 106,
#  'A_detail_request U_answer <UNK>': 105,
#  'A_sequence_closer A_confirmation A_detail_request': 105,
#  'U_greeting U_answer U_sequence_closer': 105,
#  'U_sequence_closer U_greeting U_sequence_closer': 105,
#  'U_partial_request A_grant U_greeting U_confirmation': 105,
#  'U_answer U_greeting <UNK>': 105,
#  'A_hold_request U_confirmation': 104,
#  '<UNK> A_greeting U_confirmation': 104,
#  'A_grant A_greeting U_confirmation': 103,
#  'U_sequence_closer A_sequence_closer U_sequence_closer': 102,
#  'A_sequence_closer U_confirmation A_detail_request': 102,
#  'A_sequence_closer A_sequence_closer U_sequence_closer': 102,
#  '<UNK> U_greeting U_confirmation': 102,
#  'A_sequence_closer A_detail_request <UNK>': 101,
#  'U_answer A_repair_initiator A_detail_request': 100,
#  'A_confirmation A_sequence_closer A_detail_request': 100,
#  'A_confirmation U_greeting': 100,
#  'U_partial_request U_answer A_confirmation': 99,
#  'A_grant A_confirmation': 99,
#  '<UNK> U_sequence_closer U_partial_request': 99,
#  'A_grant U_sequence_closer <UNK>': 99,
#  'A_receipt U_sequence_closer <ee>': 98,
#  'A_confirmation A_sequence_closer <UNK>': 96,
#  'A_greeting U_greeting A_detail_request': 96,
#  'A_confirmation A_grant A_greeting': 96,
#  'U_answer <UNK> A_greeting A_detail_request': 96,
#  'U_sequence_closer A_greeting A_confirmation': 95,
#  'A_confirmation A_grant U_greeting': 95,
#  'U_sequence_closer U_answer A_sequence_closer <ee>': 94,
#  'U_answer A_greeting U_confirmation': 94,
#  'A_receipt A_sequence_closer A_sequence_closer': 94,
#  'U_sequence_closer A_sequence_closer A_sequence_closer': 94,
#  'A_confirmation U_partial_request': 94,
#  'U_confirmation U_answer U_confirmation': 92,
#  'U_confirmation U_answer <UNK> U_sequence_closer': 92,
#  'U_sequence_closer U_sequence_closer U_sequence_closer <ee>': 92,
#  'A_sequence_closer A_detail_request U_partial_request U_answer': 92,
#  '<UNK> U_confirmation U_partial_request': 91,
#  'A_detail_request U_greeting U_partial_request U_answer': 91,
#  'A_greeting A_confirmation A_detail_request': 91,
#  '<UNK> U_greeting U_partial_request': 90,
#  'U_partial_request A_detail_request A_grant': 90,
#  'U_greeting <UNK> U_partial_request': 90,
#  'A_greeting <UNK> A_detail_request': 89,
#  'A_greeting U_sequence_closer': 89,
#  'A_repair_initiator A_grant': 89,
#  'U_confirmation U_confirmation': 88,
#  'U_sequence_closer <UNK> U_sequence_closer <ee>': 88,
#  'A_sequence_closer <UNK> A_sequence_closer': 88,
#  '<UNK> U_sequence_closer A_sequence_closer': 88,
#  'U_confirmation U_answer <UNK> A_greeting': 88,
#  'A_sequence_closer A_greeting U_confirmation': 88,
#  'A_completion_check A_detail_request A_greeting': 87,
#  'U_sequence_closer U_confirmation U_partial_request': 86,
#  'A_greeting A_grant U_sequence_closer U_partial_request': 86,
#  'U_answer A_completion_check A_detail_request': 85,
#  'A_greeting A_confirmation A_grant U_partial_request': 85,
#  'A_confirmation <UNK> A_detail_request': 84,
#  'A_grant A_hold_request <UNK>': 84,
#  'U_answer <UNK> U_sequence_closer': 84,
#  'U_completion_check U_partial_request': 84,
#  'A_grant A_greeting U_partial_request': 83,
#  'U_partial_request A_grant <UNK> U_confirmation': 83,
#  'A_disconfirmation A_sequence_closer': 82,
#  '<UNK> U_sequence_closer A_sequence_closer <ee>': 81,
#  'A_sequence_closer U_greeting A_confirmation': 81,
#  'A_sequence_closer A_detail_request U_greeting U_confirmation': 81,
#  'U_greeting U_partial_request U_answer': 81,
#  '<UNK> U_sequence_closer A_confirmation': 80,
#  'U_greeting U_answer A_sequence_closer': 80,
#  'A_greeting A_sequence_closer': 80,
#  'A_grant A_greeting <UNK>': 80,
#  'U_confirmation U_sequence_closer A_detail_request': 79,
#  'A_sequence_closer U_sequence_closer A_detail_request': 79,
#  'A_sequence_closer A_detail_request U_sequence_closer U_answer': 79,
#  '<UNK> U_sequence_closer A_greeting': 79,
#  'A_sequence_closer <UNK> U_sequence_closer <ee>': 79,
#  'U_greeting U_partial_request U_answer A_greeting': 79,
#  'U_greeting A_greeting A_confirmation': 79,
#  '<UNK> A_sequence_closer U_sequence_closer': 79,
#  'U_partial_request A_greeting A_grant <UNK>': 79,
#  'U_greeting U_answer <UNK> U_confirmation': 78,
#  '<UNK> <UNK> <UNK> A_greeting A_detail_request': 78,
#  'A_confirmation A_grant <UNK> U_partial_request': 78,
#  'U_greeting U_answer U_greeting <UNK>': 78,
#  'U_greeting U_answer U_greeting A_confirmation': 78,
#  'A_grant U_sequence_closer U_sequence_closer': 78,
#  'U_answer A_greeting <UNK>': 77,
#  'U_greeting U_confirmation U_partial_request': 77,
#  'A_sequence_closer A_detail_request U_greeting': 77,
#  'U_partial_request A_greeting A_confirmation A_grant U_greeting': 77,
#  'U_answer A_grant A_detail_request': 76,
#  'U_confirmation U_answer <UNK> U_partial_request': 75,
#  'A_greeting U_greeting <UNK> A_detail_request': 75,
#  'A_confirmation <UNK> U_confirmation': 74,
#  'U_partial_request A_grant <UNK> U_partial_request': 74,
#  'U_answer A_detail_request U_partial_request': 74,
#  'A_sequence_closer A_hold_request A_detail_request': 74,
#  'U_confirmation U_answer A_greeting U_confirmation': 73,
#  'A_completion_check A_detail_request U_confirmation': 73,
#  'U_confirmation U_sequence_closer U_greeting': 73,
#  'U_confirmation U_answer U_sequence_closer A_confirmation': 72,
#  'U_sequence_closer A_confirmation <UNK>': 72,
#  'A_grant U_partial_request U_partial_request': 72,
#  '<UNK> <UNK> U_sequence_closer': 72,
#  '<UNK> <UNK> U_confirmation <UNK>': 71,
#  'U_answer <UNK> A_greeting A_confirmation': 71,
#  'A_sequence_closer <UNK> A_greeting A_detail_request': 71,
#  'A_grant <UNK> A_detail_request': 71,
#  'U_partial_request A_grant <UNK> U_greeting': 71,
#  'A_detail_request A_confirmation <UNK>': 71,
#  'A_grant U_sequence_closer U_greeting': 71,
#  'A_detail_request A_greeting A_confirmation': 70,
#  'A_completion_check A_detail_request U_partial_request': 70,
#  'A_grant A_sequence_closer': 70,
#  'A_greeting A_detail_request U_greeting U_partial_request U_answer': 70,
#  'U_sequence_closer U_sequence_closer <UNK> A_sequence_closer <ee>': 69,
#  'U_sequence_closer U_sequence_closer A_sequence_closer A_sequence_closer <ee>': 69,
#  'U_sequence_closer U_sequence_closer A_detail_request': 69,
#  'A_hold_request A_detail_request': 69,
#  'A_greeting A_detail_request U_partial_request U_answer': 69,
#  'A_sequence_closer A_request_summary A_confirmation A_detail_request': 68,
#  'A_receipt A_sequence_closer <UNK>': 68,
#  'U_sequence_closer U_partial_request U_greeting': 68,
#  'U_answer A_detail_request U_confirmation': 67,
#  'A_greeting A_confirmation A_grant <UNK>': 67,
#  'U_answer U_greeting A_detail_request': 67,
#  'A_greeting A_grant <UNK> U_greeting': 67,
#  'U_sequence_closer <UNK> A_greeting A_detail_request': 66,
#  'U_confirmation <UNK> A_confirmation': 66,
#  'U_sequence_closer U_partial_request U_confirmation': 66,
#  'A_sequence_closer A_detail_request A_grant': 66,
#  'A_confirmation A_grant U_sequence_closer U_partial_request': 66,
#  'U_sequence_closer A_sequence_closer <UNK>': 65,
#  'A_hold_request A_greeting': 65,
#  '<UNK> A_sequence_closer <UNK>': 65,
#  'A_sequence_closer <UNK> A_sequence_closer <ee>': 65,
#  'A_receipt A_greeting': 65,
#  'U_answer A_confirmation U_confirmation': 64,
#  'U_answer A_confirmation <UNK> A_confirmation': 64,
#  'A_confirmation A_confirmation': 64,
#  'A_sequence_closer U_sequence_closer U_sequence_closer': 64,
#  'U_answer <UNK> U_greeting': 64,
#  'A_grant U_confirmation U_greeting': 64,
#  'U_answer U_confirmation A_confirmation': 63,
#  'U_answer A_detail_request A_detail_request': 63,
#  'A_sequence_closer A_sequence_closer U_confirmation': 63,
#  'U_sequence_closer U_answer A_confirmation': 63,
#  'U_repair_initiator U_partial_request': 63,
#  'U_sequence_closer U_partial_request A_greeting A_confirmation A_grant U_confirmation': 63,
#  'A_detail_request U_greeting U_partial_request U_answer A_greeting': 62,
#  '<UNK> <UNK> A_greeting A_confirmation': 61,
#  'U_confirmation U_sequence_closer A_greeting': 61,
#  'A_sequence_closer U_confirmation A_confirmation': 60,
#  'A_greeting U_greeting U_greeting': 60,
#  'A_receipt <UNK> <ee>': 60,
#  'U_sequence_closer U_sequence_closer <UNK> <ee>': 60,
#  'U_partial_request U_answer A_detail_request': 60,
#  'U_answer A_grant U_sequence_closer': 60,
#  'U_sequence_closer <UNK> A_greeting U_confirmation': 60,
#  'A_sequence_closer A_grant A_greeting': 60,
#  'U_sequence_closer U_greeting A_confirmation': 60,
#  '<UNK> A_sequence_closer U_confirmation': 59,
#  'U_greeting U_greeting <UNK>': 59,
#  'A_sequence_closer A_greeting A_confirmation': 59,
#  'A_grant U_partial_request A_detail_request': 59,
#  'U_greeting U_greeting A_greeting': 59,
#  'A_greeting A_detail_request U_greeting U_partial_request U_answer A_greeting': 59,
#  'A_request_summary A_detail_request': 58,
#  'U_sequence_closer A_hold_request <UNK>': 58,
#  'U_greeting A_greeting <UNK>': 58,
#  'A_receipt A_sequence_closer U_sequence_closer': 58,
#  'A_greeting <UNK> U_partial_request': 58,
#  'U_answer <UNK> A_sequence_closer': 57,
#  '<UNK> A_hold_request <UNK>': 57,
#  'A_sequence_closer <UNK> U_sequence_closer <UNK>': 57,
#  'U_confirmation A_sequence_closer': 57,
#  'A_detail_request A_grant A_detail_request': 57,
#  '<UNK> U_partial_request <UNK>': 56,
#  'U_answer U_confirmation <UNK>': 56,
#  'U_answer U_partial_request A_confirmation': 56,
#  'U_sequence_closer U_sequence_closer U_greeting': 56,
#  '<UNK> U_partial_request A_confirmation': 56,
#  'A_sequence_closer A_confirmation <UNK>': 56,
#  'U_partial_request A_greeting A_confirmation A_grant <UNK>': 56,
#  '<UNK> <UNK> A_sequence_closer': 55,
#  'A_sequence_closer <UNK> U_greeting': 55,
#  'U_partial_request A_grant A_detail_request': 54,
#  'U_greeting U_answer <UNK> A_greeting A_detail_request': 54,
#  '<UNK> <UNK> U_sequence_closer <UNK>': 54,
#  'A_greeting A_grant U_confirmation U_partial_request': 54,
#  'A_confirmation A_detail_request A_grant': 54,
#  '<UNK> A_sequence_closer A_sequence_closer': 53,
#  'A_detail_request <UNK> A_detail_request': 53,
#  '<UNK> U_confirmation U_sequence_closer': 53,
#  '<UNK> U_partial_request A_detail_request': 53,
#  '<UNK> U_sequence_closer A_detail_request': 53,
#  '<UNK> <UNK> <UNK> A_greeting': 53,
#  'A_sequence_closer A_grant U_confirmation': 53,
#  'U_answer <ee>': 53,
#  'U_partial_request A_grant U_sequence_closer U_partial_request': 53,
#  'U_answer A_grant U_greeting': 53,
#  'A_greeting A_confirmation <UNK>': 52,
#  'A_grant U_sequence_closer A_greeting': 52,
#  'U_confirmation U_sequence_closer <UNK> U_confirmation': 52,
#  '<UNK> A_receipt A_sequence_closer': 51,
#  '<UNK> A_detail_request U_confirmation': 51,
#  '<UNK> A_sequence_closer A_sequence_closer <ee>': 51,
#  'U_confirmation U_answer A_greeting <UNK>': 51,
#  'U_answer A_request_summary A_confirmation A_detail_request': 51,
#  'A_sequence_closer A_hold_request A_greeting': 51,
#  'A_completion_check A_detail_request A_confirmation': 51,
#  'A_completion_check A_detail_request <UNK>': 50,
#  'A_detail_request U_sequence_closer U_answer': 50,
#  'U_partial_request U_answer <UNK>': 50,
#  'A_greeting A_confirmation A_grant U_confirmation': 50,
#  'U_sequence_closer U_sequence_closer <UNK> U_confirmation': 49,
#  'U_confirmation <UNK> U_partial_request': 49,
#  '<UNK> U_confirmation A_detail_request': 49,
#  'U_greeting U_partial_request A_confirmation': 49,
#  'U_answer A_sequence_closer <UNK>': 49,
#  'A_repair_initiator A_greeting': 49,
#  'U_answer A_disconfirmation U_confirmation': 48,
#  'U_confirmation U_answer A_sequence_closer A_detail_request': 48,
#  'U_sequence_closer U_answer U_confirmation': 48,
#  'U_confirmation U_answer U_greeting <UNK>': 48,
#  'A_greeting <UNK> U_confirmation': 48,
#  'U_repair_initiator U_answer': 48,
#  'A_grant U_partial_request U_answer': 48,
#  'U_sequence_closer U_answer U_greeting': 48,
#  'U_greeting U_answer U_partial_request A_detail_request': 48,
#  'U_partial_request A_hold_request A_grant <UNK>': 48,
#  'U_confirmation U_answer A_sequence_closer <ee>': 47,
#  'A_grant U_answer U_partial_request': 47,
#  'U_partial_request A_grant A_greeting': 47,
#  'A_greeting A_grant A_greeting U_greeting': 47,
#  'A_sequence_closer A_sequence_closer <UNK>': 46,
#  'U_receipt <ee>': 46,
#  'U_greeting U_answer U_confirmation': 46,
#  '<UNK> U_partial_request U_partial_request': 46,
#  'U_confirmation U_answer A_hold_request <UNK>': 46,
#  '<UNK> U_confirmation A_confirmation': 46,
#  'U_sequence_closer U_greeting U_confirmation': 46,
#  'U_confirmation U_answer U_greeting A_confirmation': 46,
#  '<UNK> U_sequence_closer U_greeting': 46,
#  'A_confirmation A_detail_request A_detail_request': 46,
#  'U_greeting A_confirmation A_detail_request': 46,
#  'U_confirmation U_partial_request U_answer': 46,
#  'U_partial_request A_repair_initiator A_detail_request': 46,
#  'U_partial_request A_greeting A_grant U_sequence_closer': 46,
#  'U_sequence_closer U_confirmation A_confirmation': 45,
#  'U_confirmation <ee>': 45,
#  'A_sequence_closer U_sequence_closer A_sequence_closer': 45,
#  'A_hold_request <UNK> U_partial_request': 45,
#  'U_sequence_closer A_sequence_closer U_confirmation': 45,
#  'A_greeting U_greeting A_greeting': 45,
#  '<UNK> <UNK> <UNK> A_greeting <UNK>': 45,
#  'A_detail_request A_grant U_confirmation': 45,
#  'A_sequence_closer U_confirmation U_partial_request': 45,
#  'U_partial_request U_sequence_closer': 45,
#  'U_partial_request A_greeting A_confirmation': 45,
#  'U_partial_request A_sequence_closer': 45,
#  'A_greeting A_grant U_confirmation U_sequence_closer': 45,
#  'U_greeting U_answer <UNK> A_greeting': 44,
#  '<UNK> A_confirmation U_confirmation': 44,
#  'U_answer A_grant <UNK> A_confirmation': 44,
#  'U_confirmation U_answer <UNK> U_greeting': 44,
#  '<UNK> A_detail_request A_detail_request': 43,
#  'A_disconfirmation U_confirmation': 43,
#  'U_confirmation U_sequence_closer A_confirmation': 43,
#  'U_greeting U_answer U_greeting A_detail_request': 43,
#  'A_greeting A_greeting <UNK>': 43,
#  'U_answer A_confirmation A_confirmation': 43,
#  '<UNK> A_greeting U_partial_request': 43,
#  'U_sequence_closer A_receipt A_sequence_closer <ee>': 43,
#  'U_sequence_closer <UNK> U_sequence_closer <UNK>': 43,
#  'A_sequence_closer A_grant U_partial_request': 43,
#  'U_sequence_closer U_sequence_closer A_sequence_closer A_sequence_closer': 43,
#  'U_partial_request A_confirmation A_grant': 43,
#  'A_sequence_closer U_greeting <UNK>': 43,
#  'U_partial_request A_grant U_sequence_closer U_greeting': 43,
#  'A_grant A_greeting U_greeting': 43,
#  'A_confirmation A_grant <UNK> A_confirmation': 42,
#  '<UNK> <UNK> A_confirmation A_detail_request': 42,
#  'U_sequence_closer U_partial_request A_detail_request A_grant': 42,
#  'U_answer A_confirmation <UNK> A_detail_request': 42,
#  '<UNK> U_greeting A_confirmation': 42,
#  'A_sequence_closer U_sequence_closer A_greeting': 42,
#  'A_sequence_closer A_hold_request U_sequence_closer': 42,
#  '<UNK> U_greeting U_sequence_closer': 42,
#  'A_sequence_closer U_greeting U_confirmation': 42,
#  'A_greeting A_grant A_greeting U_confirmation': 42,
#  'A_sequence_closer A_grant U_sequence_closer': 41,
#  'A_grant U_partial_request U_confirmation': 41,
#  'A_greeting A_confirmation A_completion_check A_detail_request': 41,
#  'A_grant U_partial_request <UNK>': 41,
#  'A_repair_initiator <UNK>': 41,
#  '<UNK> A_receipt A_sequence_closer <ee>': 41,
#  'U_greeting U_sequence_closer U_answer': 41,
#  'U_disconfirmation U_sequence_closer': 41,
#  'U_answer A_grant A_greeting': 41,
#  'U_partial_request U_greeting <UNK>': 41,
#  'A_confirmation A_grant U_sequence_closer <UNK>': 40,
#  'A_hold_request U_sequence_closer': 40,
#  'A_sequence_closer A_hold_request A_hold_request <UNK>': 40,
#  '<UNK> <UNK> U_greeting <UNK>': 40,
#  '<UNK> <UNK> U_sequence_closer <ee>': 40,
#  'U_partial_request A_grant U_confirmation U_partial_request': 40,
#  'U_answer <UNK> A_hold_request <UNK>': 39,
#  'U_sequence_closer A_confirmation A_detail_request': 39,
#  'U_confirmation <UNK> U_confirmation': 39,
#  'A_detail_request A_grant U_partial_request': 39,
#  'A_detail_request U_answer U_partial_request': 39,
#  'A_greeting A_grant A_detail_request': 39,
#  '<UNK> <UNK> U_confirmation U_partial_request': 39,
#  'U_confirmation <UNK> A_detail_request': 39,
#  '<UNK> A_greeting A_sequence_closer': 39,
#  'A_grant U_sequence_closer A_sequence_closer': 39,
#  'A_confirmation A_grant A_hold_request <UNK>': 39,
#  'A_greeting A_grant U_confirmation U_greeting': 39,
#  'U_greeting U_sequence_closer U_partial_request': 39,
#  'A_grant U_greeting U_sequence_closer': 39,
#  'U_confirmation U_answer <UNK> A_greeting A_detail_request': 38,
#  'U_answer <UNK> A_confirmation A_detail_request': 38,
#  '<UNK> U_sequence_closer U_sequence_closer <ee>': 38,
#  'U_confirmation U_sequence_closer <ee>': 38,
#  'A_confirmation A_grant A_confirmation': 38,
#  'A_detail_request U_answer <UNK> A_confirmation': 38,
#  'A_sequence_closer A_detail_request A_greeting': 38,
#  'A_grant U_confirmation A_confirmation': 38,
#  'A_detail_request A_grant A_confirmation': 38,
#  'U_sequence_closer U_greeting U_greeting': 38,
#  'A_grant <UNK> U_sequence_closer': 38,
#  'A_detail_request A_grant A_confirmation A_detail_request': 37,
#  'U_answer A_request_summary A_detail_request': 37,
#  'U_partial_request A_greeting A_detail_request': 37,
#  'U_answer <UNK> U_greeting <UNK>': 37,
#  'U_answer A_hold_request A_detail_request': 37,
#  '<UNK> A_confirmation A_greeting': 37,
#  'A_receipt A_sequence_closer U_confirmation': 37,
#  'A_detail_request A_grant A_greeting': 37,
#  'A_disconfirmation <UNK>': 36,
#  'U_sequence_closer U_sequence_closer <UNK> A_sequence_closer': 36,
#  'U_sequence_closer A_detail_request U_confirmation': 36,
#  'A_sequence_closer U_sequence_closer A_confirmation': 36,
#  'A_confirmation A_grant <UNK> A_detail_request': 36,
#  'U_sequence_closer A_receipt A_sequence_closer': 36,
#  'U_confirmation U_answer <UNK> A_greeting A_confirmation': 36,
#  'A_sequence_closer A_grant A_confirmation': 36,
#  'U_sequence_closer U_sequence_closer U_sequence_closer A_sequence_closer': 36,
#  '<UNK> <UNK> A_greeting U_confirmation': 36,
#  'U_confirmation U_answer U_confirmation A_confirmation': 36,
#  '<UNK> A_repair_initiator A_detail_request': 36,
#  'A_greeting A_grant A_greeting U_partial_request': 36,
#  'U_sequence_closer <UNK> U_sequence_closer A_greeting': 35,
#  'U_sequence_closer U_answer A_greeting': 35,
#  'U_answer A_hold_request U_confirmation': 35,
#  'U_answer A_greeting A_confirmation <UNK>': 35,
#  'U_partial_request A_request_summary A_confirmation': 35,
#  '<UNK> <UNK> A_greeting A_greeting': 35,
#  'A_confirmation A_detail_request U_partial_request': 35,
#  'U_partial_request U_answer U_partial_request': 35,
#  '<UNK> U_greeting A_greeting': 35,
#  '<UNK> <UNK> U_greeting U_confirmation': 35,
#  'A_grant U_confirmation U_confirmation': 34,
#  '<UNK> U_sequence_closer A_sequence_closer A_sequence_closer': 34,
#  'U_confirmation U_answer U_confirmation <UNK>': 34,
#  'U_partial_request A_sequence_closer A_grant': 34,
#  'A_detail_request U_answer A_greeting A_confirmation': 34,
#  'A_sequence_closer <UNK> U_sequence_closer U_sequence_closer': 34,
#  'U_greeting U_answer <UNK> A_greeting A_confirmation': 34,
#  'A_receipt A_detail_request': 34,
#  'A_sequence_closer A_detail_request U_greeting U_partial_request': 34,
#  'A_grant U_sequence_closer A_confirmation': 34,
#  'U_answer A_greeting U_partial_request': 34,
#  'U_disconfirmation U_answer A_detail_request': 33,
#  'U_sequence_closer U_partial_request A_greeting': 33,
#  'A_confirmation A_sequence_closer U_confirmation': 33,
#  'A_sequence_closer U_greeting A_detail_request': 33,
#  'U_sequence_closer U_confirmation A_detail_request': 33,
#  'U_sequence_closer A_greeting A_sequence_closer': 33,
#  'U_answer A_sequence_closer A_greeting': 33,
#  'A_sequence_closer U_confirmation A_greeting': 33,
#  '<UNK> <UNK> <ee>': 33,
#  'A_greeting A_confirmation A_grant': 33,
#  'U_greeting U_answer U_partial_request A_confirmation': 33,
#  'U_partial_request A_grant A_greeting U_confirmation': 33,
#  'A_greeting A_detail_request U_confirmation U_partial_request': 33,
#  'A_greeting A_grant A_greeting <UNK>': 33,
#  'U_partial_request A_greeting A_grant U_greeting U_confirmation': 33,
#  'U_sequence_closer U_answer U_sequence_closer A_confirmation': 32,
#  'A_detail_request U_confirmation U_partial_request': 32,
#  'A_confirmation A_sequence_closer <ee>': 32,
#  'A_repair_initiator A_confirmation': 32,
#  '<UNK> U_greeting A_detail_request': 32,
#  'A_completion_check A_detail_request A_detail_request': 32,
#  'A_confirmation A_hold_request <UNK>': 32,
#  'A_detail_request A_greeting A_detail_request': 32,
#  'U_sequence_closer <UNK> A_receipt A_sequence_closer': 32,
#  'U_confirmation U_answer <UNK> A_sequence_closer': 32,
#  'U_confirmation U_sequence_closer A_sequence_closer <ee>': 32,
#  'U_sequence_closer <UNK> A_sequence_closer <UNK>': 32,
#  'U_answer U_sequence_closer <ee>': 32,
#  'U_sequence_closer <UNK> A_greeting A_confirmation': 32,
#  'A_sequence_closer U_sequence_closer U_partial_request': 32,
#  'A_greeting A_greeting U_confirmation': 32,
#  'U_sequence_closer U_sequence_closer U_sequence_closer U_sequence_closer': 32,
#  '<UNK> U_greeting U_greeting': 32,
#  'A_confirmation A_sequence_closer <UNK> U_confirmation': 31,
#  'U_answer <UNK> U_sequence_closer <UNK>': 31,
#  'U_answer A_request_summary A_confirmation': 31,
#  '<UNK> A_detail_request <UNK>': 31,
#  'A_disconfirmation A_grant U_partial_request': 31,
#  'U_answer A_disconfirmation U_partial_request': 31,
#  'A_greeting A_grant U_sequence_closer U_greeting': 31,
#  'A_grant U_partial_request U_greeting': 31,
#  'A_detail_request A_grant A_greeting U_greeting': 31,
#  'U_confirmation U_answer U_greeting A_detail_request': 30,
#  'U_answer A_detail_request U_sequence_closer': 30,
#  '<UNK> A_greeting U_sequence_closer': 30,
#  'A_greeting A_detail_request U_greeting U_partial_request U_answer A_detail_request': 30,
#  'A_detail_request U_answer <UNK> A_detail_request': 30,
#  'A_confirmation A_sequence_closer A_greeting': 30,
#  'U_answer U_partial_request <UNK>': 30,
#  'U_confirmation U_answer A_sequence_closer U_confirmation': 30,
#  '<UNK> A_greeting A_greeting <UNK>': 30,
#  'U_partial_request A_disconfirmation A_grant': 30,
#  'A_sequence_closer A_completion_check A_detail_request U_confirmation': 30,
#  'U_greeting U_partial_request A_detail_request': 30,
#  'U_answer U_sequence_closer <UNK>': 29,
#  'U_partial_request <UNK> A_confirmation': 29,
#  'U_partial_request A_grant U_confirmation <UNK>': 29,
#  'U_answer U_partial_request A_detail_request': 29,
#  'U_confirmation U_answer U_partial_request A_confirmation': 29,
#  'U_confirmation U_answer A_sequence_closer A_greeting': 29,
#  'U_sequence_closer U_greeting A_detail_request': 29,
#  'U_sequence_closer A_hold_request U_confirmation': 29,
#  'A_greeting A_grant U_confirmation <UNK>': 29,
#  'U_sequence_closer <UNK> A_sequence_closer A_sequence_closer <ee>': 29,
#  'U_sequence_closer A_greeting U_partial_request': 29,
#  '<UNK> A_detail_request U_partial_request': 29,
#  'U_answer <UNK> A_detail_request A_detail_request': 29,
#  'A_confirmation A_detail_request U_confirmation': 29,
#  'A_grant A_greeting <UNK> U_partial_request': 29,
#  'U_sequence_closer U_greeting A_greeting': 29,
#  'U_sequence_closer A_detail_request U_partial_request': 29,
#  'U_answer U_greeting U_sequence_closer': 29,
#  '<UNK> U_confirmation U_greeting': 29,
#  'A_grant U_sequence_closer U_confirmation': 29,
#  'A_request_summary A_request_summary A_confirmation A_detail_request': 29,
#  'A_detail_request A_sequence_closer': 28,
#  'U_answer A_hold_request A_hold_request <UNK>': 28,
#  'U_receipt U_sequence_closer <ee>': 28,
#  '<UNK> A_sequence_closer A_greeting': 28,
#  '<UNK> <UNK> <UNK> U_greeting': 28,
#  '<UNK> <UNK> A_confirmation <UNK>': 28,
#  'A_confirmation A_sequence_closer U_sequence_closer <ee>': 28,
#  '<UNK> <UNK> <UNK> U_confirmation <UNK>': 28,
#  'A_confirmation <UNK> U_partial_request': 28,
#  '<UNK> A_confirmation U_sequence_closer': 28,
#  'U_confirmation U_sequence_closer U_confirmation': 28,
#  'A_confirmation U_confirmation <UNK>': 28,
#  'A_sequence_closer A_hold_request A_confirmation': 28,
#  'A_confirmation A_grant <UNK> U_greeting': 28,
#  'U_sequence_closer U_partial_request A_greeting A_confirmation A_grant': 28,
#  'A_grant U_greeting <UNK>': 28,
#  'U_partial_request A_greeting A_grant A_greeting': 28,
#  'A_sequence_closer U_sequence_closer <UNK> U_confirmation': 27,
#  'U_sequence_closer U_confirmation U_greeting': 27,
#  'U_answer <UNK> A_sequence_closer <ee>': 27,
#  'U_sequence_closer <UNK> A_receipt A_sequence_closer <ee>': 27,
#  '<UNK> A_greeting A_confirmation <UNK>': 27,
#  'U_confirmation U_answer A_greeting A_sequence_closer': 27,
#  'U_sequence_closer A_greeting U_sequence_closer': 27,
#  '<UNK> A_request_summary A_confirmation A_detail_request': 27,
#  'U_sequence_closer <UNK> U_sequence_closer U_sequence_closer': 27,
#  '<UNK> A_greeting U_greeting': 27,
#  'A_hold_request A_grant A_greeting': 27,
#  'U_answer U_greeting A_greeting': 27,
#  'A_greeting A_detail_request A_grant': 27,
#  'U_disconfirmation <UNK>': 27,
#  'U_sequence_closer <UNK> A_sequence_closer A_sequence_closer': 27,
#  'A_greeting A_detail_request <UNK>': 27,
#  'U_answer A_hold_request A_grant': 27,
#  'A_confirmation A_greeting A_detail_request': 27,
#  'U_answer A_grant <UNK> A_detail_request': 27,
#  'U_sequence_closer U_sequence_closer <UNK> U_sequence_closer': 27,
#  'A_sequence_closer U_greeting A_greeting': 27,
#  'U_confirmation U_sequence_closer U_greeting U_partial_request': 27,
#  '<UNK> <UNK> U_sequence_closer A_greeting': 26,
#  'A_detail_request <UNK> U_partial_request': 26,
#  'U_answer A_detail_request <UNK>': 26,
#  'U_confirmation U_answer A_sequence_closer <UNK>': 26,
#  'U_confirmation U_answer U_sequence_closer <UNK>': 26,
#  'U_partial_request A_grant A_hold_request <UNK>': 26,
#  'U_partial_request A_confirmation A_detail_request': 26,
#  'U_greeting U_greeting A_confirmation': 26,
#  'A_greeting A_confirmation U_confirmation': 26,
#  'U_answer A_confirmation U_partial_request': 26,
#  'A_grant A_hold_request U_confirmation': 26,
#  '<UNK> U_sequence_closer U_confirmation': 26,
#  '<UNK> <UNK> U_sequence_closer U_partial_request': 26,
#  'U_sequence_closer <UNK> U_sequence_closer A_confirmation': 26,
#  'A_greeting U_confirmation <UNK>': 26,
#  'A_sequence_closer A_hold_request A_greeting <UNK>': 26,
#  'A_sequence_closer A_confirmation A_greeting': 26,
#  'A_disconfirmation A_sequence_closer A_detail_request': 26,
#  'U_greeting A_greeting <UNK> A_confirmation': 26,
#  'U_sequence_closer <UNK> U_greeting U_confirmation': 26,
#  'A_greeting U_confirmation U_partial_request': 26,
#  'U_sequence_closer A_confirmation U_confirmation': 26,
#  'A_completion_check A_detail_request A_sequence_closer': 26,
#  '<UNK> U_partial_request U_confirmation': 26,
#  'A_grant A_greeting U_sequence_closer': 26,
#  'A_sequence_closer A_greeting U_partial_request': 26,
#  'U_partial_request A_grant U_confirmation U_greeting': 26,
#  'A_sequence_closer A_hold_request A_grant': 26,
#  'U_answer U_sequence_closer A_detail_request': 25,
#  'U_answer <UNK> U_sequence_closer U_partial_request': 25,
#  'U_answer <UNK> A_greeting U_confirmation': 25,
#  'U_greeting U_answer A_repair_initiator A_detail_request': 25,
#  'A_grant U_sequence_closer A_detail_request': 25,
#  'A_receipt <UNK> A_sequence_closer': 25,
#  'U_greeting U_answer <UNK> U_greeting <UNK>': 25,
#  'U_confirmation U_answer A_detail_request U_confirmation': 25,
#  'U_confirmation U_answer A_detail_request A_detail_request': 25,
#  'A_detail_request U_answer A_greeting': 25,
#  'A_sequence_closer A_greeting U_sequence_closer': 25,
#  '<UNK> <UNK> U_sequence_closer A_sequence_closer <ee>': 25,
#  '<UNK> U_confirmation A_greeting': 25,
#  'A_request_summary U_sequence_closer': 25,
#  'A_sequence_closer A_hold_request <UNK> A_detail_request': 25,
#  '<UNK> U_confirmation U_confirmation': 25,
#  'A_confirmation A_confirmation <UNK>': 25,
#  'U_sequence_closer <UNK> U_sequence_closer U_partial_request': 25,
#  'U_greeting U_answer U_greeting A_greeting': 25,
#  '<UNK> <UNK> U_sequence_closer A_confirmation': 25,
#  'U_greeting U_answer U_partial_request <UNK>': 25,
#  'A_completion_check A_detail_request A_grant': 25,
#  'U_greeting A_confirmation <UNK>': 25,
#  'A_greeting A_confirmation A_grant A_detail_request': 25,
#  'U_partial_request A_greeting A_confirmation A_grant U_sequence_closer U_partial_request': 25,
#  '<UNK> <UNK> U_sequence_closer U_sequence_closer': 25,
#  'A_grant U_greeting U_confirmation U_partial_request': 25,
#  'U_partial_request A_greeting A_confirmation A_grant U_sequence_closer': 25,
#  'U_sequence_closer U_sequence_closer A_sequence_closer <UNK>': 25,
#  'U_greeting U_sequence_closer <ee>': 24,
#  'U_confirmation U_answer A_completion_check A_detail_request': 24,
#  '<UNK> A_detail_request A_confirmation': 24,
#  'U_answer A_hold_request A_greeting': 24,
#  'A_grant A_confirmation <UNK>': 24,
#  'A_disconfirmation A_detail_request': 24,
#  'A_detail_request A_confirmation A_greeting': 24,
#  'U_answer A_confirmation U_sequence_closer': 24,
#  'U_confirmation U_answer U_sequence_closer <ee>': 24,
#  'A_detail_request A_grant U_greeting': 24,
#  'U_greeting U_partial_request U_greeting': 24,
#  'U_sequence_closer A_greeting U_greeting': 24,
#  'A_confirmation U_sequence_closer A_detail_request': 24,
#  '<UNK> U_partial_request A_greeting': 24,
#  '<UNK> U_partial_request U_greeting': 24,
#  'U_greeting <UNK> U_greeting': 24,
#  'A_greeting A_grant U_sequence_closer U_sequence_closer': 24,
#  'A_grant U_partial_request A_confirmation': 23,
#  'U_answer A_greeting A_sequence_closer': 23,
#  'A_hold_request <UNK> A_detail_request': 23,
#  'U_answer <UNK> A_request_summary A_confirmation A_detail_request': 23,
#  'A_completion_check A_detail_request U_sequence_closer': 23,
#  'A_hold_request A_greeting U_confirmation': 23,
#  '<UNK> <UNK> U_partial_request <UNK>': 23,
#  'U_greeting U_confirmation <UNK>': 23,
#  'A_sequence_closer A_greeting A_sequence_closer': 23,
#  'U_confirmation <UNK> A_greeting': 23,
#  'A_confirmation A_grant U_sequence_closer A_detail_request': 23,
#  'U_confirmation U_partial_request A_confirmation': 23,
#  '<UNK> A_hold_request U_confirmation': 23,
#  'U_answer A_sequence_closer U_confirmation': 23,
#  'A_confirmation A_grant U_sequence_closer A_greeting': 23,
#  'U_confirmation U_sequence_closer A_greeting U_confirmation': 23,
#  'A_greeting A_confirmation A_grant U_sequence_closer': 23,
#  'U_sequence_closer A_receipt <ee>': 23,
#  'A_confirmation A_grant A_greeting <UNK>': 23,
#  'A_request_summary U_confirmation': 23,
#  'U_greeting A_sequence_closer': 23,
#  'A_detail_request U_greeting': 23,
#  'A_greeting A_grant U_greeting U_confirmation U_partial_request': 23,
#  'A_sequence_closer <UNK> A_detail_request A_confirmation': 22,
#  'U_sequence_closer U_partial_request A_sequence_closer': 22,
#  'A_request_summary A_grant': 22,
#  'A_sequence_closer A_hold_request <UNK> U_partial_request': 22,
#  'U_sequence_closer U_confirmation A_greeting': 22,
#  'A_sequence_closer A_sequence_closer A_detail_request': 22,
#  'U_partial_request A_hold_request A_grant A_greeting': 22,
#  'A_detail_request U_answer A_greeting A_detail_request': 22,
#  'A_request_summary <UNK>': 22,
#  'A_confirmation A_greeting <UNK>': 22,
#  'U_confirmation A_greeting A_confirmation': 22,
#  '<UNK> <UNK> U_confirmation A_confirmation': 22,
#  'A_sequence_closer A_completion_check A_detail_request U_partial_request': 22,
#  'U_sequence_closer A_sequence_closer A_greeting': 22,
#  'A_greeting U_greeting U_confirmation': 22,
#  'U_sequence_closer U_answer U_confirmation <UNK>': 22,
#  'U_answer <UNK> U_sequence_closer A_greeting': 22,
#  'A_hold_request A_hold_request <UNK>': 22,
#  'U_partial_request U_partial_request U_partial_request': 22,
#  'A_sequence_closer U_partial_request A_detail_request': 22,
#  'U_confirmation U_answer A_detail_request U_partial_request': 22,
#  'A_greeting A_grant U_greeting U_sequence_closer U_partial_request': 22,
#  'U_answer U_partial_request U_partial_request': 22,
#  'U_sequence_closer U_sequence_closer U_greeting U_sequence_closer': 22,
#  'U_answer A_detail_request U_greeting': 22,
#  'U_sequence_closer <UNK> U_greeting <UNK>': 22,
#  'U_greeting U_answer U_greeting U_greeting': 22,
#  'A_greeting A_grant U_partial_request U_greeting': 21,
#  'U_sequence_closer <UNK> A_sequence_closer U_sequence_closer': 21,
#  'A_greeting A_detail_request U_confirmation': 21,
#  'U_answer <UNK> A_detail_request U_confirmation': 21,
#  'A_greeting A_confirmation A_greeting': 21,
#  '<UNK> <UNK> U_partial_request A_confirmation': 21,
#  'U_confirmation U_partial_request <UNK>': 21,
#  'U_sequence_closer A_sequence_closer A_detail_request': 21,
#  'U_answer A_detail_request A_confirmation': 21,
#  'U_sequence_closer U_sequence_closer <UNK> A_confirmation': 21,
#  '<UNK> A_sequence_closer A_detail_request': 21,
#  'U_answer U_confirmation A_detail_request': 21,
#  '<UNK> <UNK> A_sequence_closer <ee>': 21,
#  'U_partial_request A_grant A_greeting <UNK>': 21,
#  'U_sequence_closer U_greeting A_sequence_closer': 21,
#  'U_sequence_closer U_partial_request A_repair_initiator A_detail_request': 21,
#  'U_sequence_closer <UNK> U_sequence_closer A_sequence_closer': 21,
#  'A_grant <ee>': 21,
#  '<UNK> U_sequence_closer A_sequence_closer A_sequence_closer <ee>': 21,
#  'U_partial_request A_confirmation A_detail_request A_grant': 21,
#  'A_confirmation <UNK> A_greeting': 21,
#  'U_confirmation U_greeting <UNK>': 21,
#  'A_grant U_greeting U_sequence_closer U_partial_request': 21,
#  'U_answer A_disconfirmation <UNK>': 20,
#  'U_sequence_closer U_answer A_receipt': 20,
#  'U_answer <UNK> U_sequence_closer <ee>': 20,
#  '<UNK> <UNK> U_greeting A_confirmation': 20,
#  'U_confirmation U_answer A_confirmation U_confirmation': 20,
#  '<UNK> <UNK> A_request_summary A_confirmation A_detail_request': 20,
#  '<UNK> <UNK> U_sequence_closer A_sequence_closer': 20,
#  'A_repair_initiator A_detail_request A_grant': 20,
#  'A_sequence_closer <UNK> A_detail_request A_detail_request': 20,
#  'U_confirmation U_answer <UNK> U_sequence_closer U_sequence_closer': 20,
#  'U_confirmation A_greeting U_confirmation': 20,
#  'A_confirmation U_sequence_closer <UNK>': 20,
#  'A_grant <UNK> A_greeting': 20,
#  'U_sequence_closer A_confirmation U_sequence_closer': 20,
#  'A_greeting A_detail_request A_detail_request': 20,
#  'A_receipt U_confirmation': 20,
#  'U_answer A_confirmation A_greeting A_detail_request': 20,
#  'U_confirmation U_partial_request U_partial_request': 20,
#  'U_sequence_closer U_sequence_closer U_confirmation': 20,
#  'A_sequence_closer <UNK> A_sequence_closer U_sequence_closer': 20,
#  'U_partial_request A_grant U_sequence_closer <UNK>': 20,
#  'A_confirmation A_grant A_greeting U_confirmation': 20,
#  'U_sequence_closer U_answer U_sequence_closer <ee>': 20,
#  'U_partial_request A_repair_initiator A_greeting': 20,
#  'U_greeting U_answer A_greeting <UNK>': 20,
#  'U_greeting U_confirmation U_answer': 20,
#  'A_greeting A_confirmation A_grant U_greeting': 20,
#  'U_answer A_confirmation U_greeting': 20,
#  'U_greeting U_answer A_sequence_closer A_detail_request': 20,
#  'U_answer U_greeting U_greeting': 20,
#  'U_partial_request A_greeting A_grant <UNK> U_confirmation': 20,
#  'U_partial_request U_answer U_greeting': 20,
#  'U_confirmation U_greeting U_sequence_closer': 20,
#  'A_greeting A_grant U_partial_request U_partial_request': 20,
#  'U_partial_request A_grant U_greeting U_greeting': 20,
#  'A_grant <UNK> A_sequence_closer': 19,
#  '<UNK> A_receipt <ee>': 19,
#  'U_confirmation U_answer <UNK> U_sequence_closer <UNK>': 19,
#  'U_confirmation U_answer A_greeting U_sequence_closer': 19,
#  'U_sequence_closer U_answer <ee>': 19,
#  '<UNK> U_sequence_closer <UNK> U_confirmation': 19,
#  'A_sequence_closer <UNK> A_sequence_closer U_confirmation': 19,
#  'A_confirmation A_sequence_closer U_sequence_closer': 19,
#  'U_answer A_confirmation A_completion_check A_detail_request': 19,
#  'A_hold_request A_greeting <UNK>': 19,
#  'U_confirmation U_answer A_repair_initiator A_detail_request': 19,
#  'U_answer A_greeting U_sequence_closer': 19,
#  'A_confirmation A_confirmation A_detail_request': 19,
#  'U_sequence_closer A_confirmation A_greeting': 19,
#  'U_greeting U_answer A_sequence_closer <ee>': 19,
#  '<UNK> <UNK> <UNK> U_sequence_closer <UNK>': 19,
#  '<UNK> <UNK> <UNK> A_sequence_closer': 19,
#  'U_greeting U_answer A_greeting U_confirmation': 19,
#  'U_greeting U_answer A_hold_request <UNK>': 19,
#  '<UNK> U_greeting U_greeting <UNK>': 19,
#  'U_repair_initiator <UNK>': 19,
#  ...}

# %%
import matplotlib.pyplot as plt

names = list(seq_sizes.keys())
values = list(seq_sizes.values())

plt.bar(range(len(seq_sizes)), values, tick_label=names)
plt.show()

# %%
#isso seria pra plotear todos os elementos do dict
sorted_names = list(sorted_d.keys())
sorted_values = list(sorted_d.values())
sorted_len_each_seq = []

for s in seq_to_plot:
#     print(len(s), s)
    sorted_len_each_seq.append(len(s))

df_plot = pd.DataFrame(list(zip(sorted_names, sorted_values, sorted_len_each_seq)),columns =['Name', 'values', 'seq_len'])

df_plot.drop(0, axis=0, inplace=True)
df_plot.head(10)

print('sequence sizes in different ranges of sequence count:')
print('number of sequences with more than 1000 counts and their length: ')
print(df_plot['seq_len'].loc[df_plot['values'] > 1000].value_counts())
print('number of sequences between 500 and 1000 counts and their length: ')
print(df_plot['seq_len'].loc[(df_plot['values'] > 500) & (df_plot['values'] < 1000)].value_counts())
print('number of sequences with less than 500 counts and their length: ')
print(df_plot['seq_len'].loc[df_plot['values'] < 500].value_counts())
# Out:
# sequence sizes in different ranges of sequence count:
# number of sequences with more than 1000 counts and their length:
# 2    29
# 3     9
# Name: seq_len, dtype: int64
# number of sequences between 500 and 1000 counts and their length:
# 2    28
# 3    23
# 4     1
# Name: seq_len, dtype: int64
# number of sequences with less than 500 counts and their length:
# 4     3768
# 5     2667
# 3     1803
# 6      930
# 7      230
# 2      211
# 8       36
# 9        3
# 10       1
# Name: seq_len, dtype: int64

# %%
print(df_plot['seq_len'].max())
print(df_plot['seq_len'].min())
print('mean len: '+ str(df_plot['seq_len'].mean()))
df_plot.hist('seq_len', bins=9)
# Out:
# 10
# 2
# mean len: 4.309169319231954
# array([[<AxesSubplot:title={'center':'seq_len'}>]], dtype=object)
